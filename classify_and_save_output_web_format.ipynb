# %% [markdown]
# # Importações

# %%
import json
import joblib
import pandas as pd

# %% [markdown]
# # Base de Dados

# %% [markdown]
# #### Importando a entrada em formato .json:

# %%
with open('input/pe-dataset.json') as file:
    pe_dataset = json.load(file)

# %% [markdown]
# #### Transformando a entrada em um dataframe:

# %%
db_pe = pd.DataFrame.from_dict(pe_dataset, orient='index')

# %%
db_pe.head()
# Out:
#                             panel_info panel_eplet locus_abc locus_dr  \
# 0     0dfaab7bd101edb0c413798f4d19e9a1        102H         1        0
# 1     0dfaab7bd101edb0c413798f4d19e9a1        103M         1        0
# 10    0dfaab7bd101edb0c413798f4d19e9a1        11AV         1        0
# 100   0dfaab7bd101edb0c413798f4d19e9a1        71TD         1        0
# 1000  2ee8a4c5dd41332767512ca6ce6c5cf3        66DR         0        0
#
#      locus_dq locus_dp panel_nc panel_pc panel_allele_count panel_min_mfi  \
# 0           0        0      126    10803                  1           483
# 1           0        0      126    10803                  1           778
# 10          0        0      126    10803                 14             0
# 100         0        0      126    10803                  2          1069
# 1000        1        0      148    13047                  6             0
#
#      panel_max_mfi reactive
# 0              483        0
# 1              778        0
# 10            4456        0
# 100           3156        0
# 1000          1047        0

# %% [markdown]
# #### Agrupando o dataframe por painéis:

# %%
db_pe = db_pe.sort_values(by='panel_info')

# %%
db_pe.head()
# Out:
#                             panel_info panel_eplet locus_abc locus_dr  \
# 7059  007a756c2784939fc12c1b09b448c175         9YL         0        0
# 6963  007a756c2784939fc12c1b09b448c175         23L         0        0
# 6962  007a756c2784939fc12c1b09b448c175        185I         0        0
# 6961  007a756c2784939fc12c1b09b448c175        175E         0        0
# 6960  007a756c2784939fc12c1b09b448c175        160S         0        0
#
#      locus_dq locus_dp panel_nc panel_pc panel_allele_count panel_min_mfi  \
# 7059        0        1        6     6925                 11             0
# 6963        1        0        6     6925                  2          2291
# 6962        1        0        6     6925                 10          2291
# 6961        1        0        6     6925                 17          1493
# 6960        1        0        6     6925                  1         13252
#
#      panel_max_mfi reactive
# 7059          1374        0
# 6963          6306        0
# 6962         11832        0
# 6961         12696        0
# 6960         13252        0

# %%
db_pe.reset_index(level=0, inplace=True)

# %%
db_pe.head()
# Out:
#   index                        panel_info panel_eplet locus_abc locus_dr  \
# 0  7059  007a756c2784939fc12c1b09b448c175         9YL         0        0
# 1  6963  007a756c2784939fc12c1b09b448c175         23L         0        0
# 2  6962  007a756c2784939fc12c1b09b448c175        185I         0        0
# 3  6961  007a756c2784939fc12c1b09b448c175        175E         0        0
# 4  6960  007a756c2784939fc12c1b09b448c175        160S         0        0
#
#   locus_dq locus_dp panel_nc panel_pc panel_allele_count panel_min_mfi  \
# 0        0        1        6     6925                 11             0
# 1        1        0        6     6925                  2          2291
# 2        1        0        6     6925                 10          2291
# 3        1        0        6     6925                 17          1493
# 4        1        0        6     6925                  1         13252
#
#   panel_max_mfi reactive
# 0          1374        0
# 1          6306        0
# 2         11832        0
# 3         12696        0
# 4         13252        0

# %% [markdown]
# # Selecionando atributos da base

# %% [markdown]
# #### Instâncias do painel:

# %%
instances_painel = db_pe.drop(columns=['index', 'panel_info', 'panel_eplet', 'reactive'])
instances_painel.head()
# Out:
#   locus_abc locus_dr locus_dq locus_dp panel_nc panel_pc panel_allele_count  \
# 0         0        0        0        1        6     6925                 11
# 1         0        0        1        0        6     6925                  2
# 2         0        0        1        0        6     6925                 10
# 3         0        0        1        0        6     6925                 17
# 4         0        0        1        0        6     6925                  1
#
#   panel_min_mfi panel_max_mfi
# 0             0          1374
# 1          2291          6306
# 2          2291         11832
# 3          1493         12696
# 4         13252         13252

# %% [markdown]
# #### Transformando os valores categóricos em numéricos:

# %%
for column in instances_painel.columns:
    instances_painel[column] = instances_painel[column].apply(lambda x:int(x))

# %% [markdown]
# # Carregando o Modelo Persistido

# %%
# Modelo treinado com a base de SP
joblib_model = joblib.load("persisted_model/joblib_final_model.pkl")
print(joblib_model)
# Out:
# RandomForestClassifier(max_features='sqrt', min_samples_leaf=4,
#                        min_samples_split=8, n_estimators=400)

# %% [markdown]
# # Classificando Epítopos

# %%
predicted_labels_painel = joblib_model.predict(instances_painel)

# %%
def returnReactiveEplets(labels):
    painels = []
    predict_eplet = []
    painel_number = db_pe['panel_info'][0]                          # Recebe o identificador do primeiro painel
    first_react_eplet = 1                                           # Flag para controlarmos o cálculo do cutoff
    cutoff = 0                                                                                                                
    
    for index in range(0, len(labels)):                             # Percorre todas as instâncias da base
        if(db_pe['panel_info'][index] == painel_number):            # Se ainda estivermos no mesmo painel
            
            if(labels[index] == 1):                                 # Se o epítopo for classificado como reativo
                predict_eplet.append(db_pe['panel_eplet'][index])   # Adiconamos à lista de epítopos classificados como reativos
                
                if(first_react_eplet):                              # Verificamos se é o primeiro epítopo reativo daquele painel
                    cutoff = db_pe['panel_min_mfi'][index]          # Inicializamos o valor do cutoff
                    first_react_eplet = 0                           # Atualizamos o valor da flag
                    
                elif(db_pe['panel_min_mfi'][index] < cutoff):       # Verificamos se o cutoff do eplet é o menor cutoff
                    cutoff = db_pe['panel_min_mfi'][index]          # Atualizamos o valor do cutoff
        else:                                                       
            results = {                                             # Se mudarmos de painel, resetamos as análises
                    'painel': '',
                    'analysis': [],
                    'cutoff': ''
            }
            results['painel'] = painel_number                      # Preenchemos o identificador do painel
            results['analysis'] = predict_eplet                    # Preenchemos a lista de epítopos classificados como reativos
            results['cutoff'] = str(cutoff)                        # Preenchemos o valor do cutoff
            painels.append(results)                                # Adicionamos à lista de resultados
            
            painel_number = db_pe['panel_info'][index]             # Atualizamos o identificador do painel
            predict_eplet = []                                     # Resetamos a lista de epítopos classificados como reativos
            cutoff = 0                                             # Resetamos o valor do cutoff
            first_react_eplet = 1                                  # Resetamos a flag para controlarmos o cálculo do cutoff
            
    return painels

# %%
def printResults(panels):
    for index in range(0, len(panels)):
        print(panels[index])
        print("\n")

# %%
panels = returnReactiveEplets(predicted_labels_painel)
printResults(panels)
# Out:
# {'painel': '007a756c2784939fc12c1b09b448c175', 'analysis': ['23L', '185I', '175E', '160D', '160AE', '135G', '96Y<sub>2</sub>', '98E', '40ERV', '66IT', '66IL', '61FT<sub>4</sub>', '56PA', '55RL<sub>3</sub>', '55PPD', '55PPA', '55PP', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '47KHL', '45GE<sub>3</sub>', '45EV', '70QRA', '4Q', '40GR<sub>3</sub>', '65LE', '75S<sub>3</sub>', '76L', '84QL<sub>3</sub>', '75IL', '57D'], 'cutoff': '11739'}
#
#
# {'painel': '008c56d5f6c8a1b5dbe0aee2b506d185', 'analysis': ['57D', '65LE', '9H', '76I', '84DEAV', '76V', '37FV', '37FL<sub>2</sub>', '37F', '13FEY', '112Y', '37L', '125SQ', '98E', '96Y<sub>2</sub>', '78V<sub>2</sub>', '74E', '57V', '57A', '4Q', '70RE', '11M', '33EYA', '35LV', '55EA', '11L', '45GE<sub>3</sub>', '9YL', '135G'], 'cutoff': '10076'}
#
#
# {'painel': '00e9b45a8c53eb7353213770d78b2e90', 'analysis': ['11L', '11M', '31Q', '111R', '9F', '66ER', '9H', '66EV', '67VG', '67VT', '70GT', '70RT', '74EL', '74SR<sub>3</sub>', '74SV<sub>2</sub>', '77T', '85VA', '85VY', '87F', '33EYA', '65LE', '69R<sub>2</sub>', '76I', '76V', '84DEAV', '56PV', '35LV', '35YA', '55EA', '57D', '56PS', '56PD', '55RPD', '16Y', '142M<sub>3</sub>', '108T', '57DE<sup>DP</sup>', '57S', '67F', '70DA', '70DK', '70DRA', '70QE', '58EE<sup>DP</sup>', '70QKA', '26L', '13FEY', '57DE', '56EE<sup>DR11</sup>', '56E<sup>DR11</sup>', '40YD<sub>2</sub>', '28DHF', '37YV', '37L', '37D<sub>2</sub>', '31FYY', '30G', '28H', '37S', '41RA<sub>2</sub>', '45EV', '45GV', '46VY<sub>3</sub>', '9YL', '52PL<sub>3</sub>', '52PR', '52SK<sub>5</sub>', '55PP', '55PPA', '55PPD', '55RL<sub>3</sub>', '52PQ<sub>2</sub>', '37YV', '37YA', '30Y', '71A', '71E', '74L', '85A', '96EN<sub>3</sub>', '96ES<sub>2</sub>', '96EV', '96Y<sub>2</sub>', '125G', '167H<sub>2</sub>', '185I', '30H', '13FE'], 'cutoff': '1009'}
#
#
# {'painel': '011f6a48531370a817d4eb78435479ab', 'analysis': ['163LS/G', '166DG', '166ES', '158T', '138K', '71SA', '76ESI', '80I+90A', '82LR+138M', '82LR+144QR', '82LR+145R', '82LR+145RA', '80I+69TNT', '80I', '65RNA+80I', '66IF+163TEW'], 'cutoff': '15687'}
#
#
# {'painel': '016f986cc1b600634610d0dd41cafeba', 'analysis': ['55PPA', '160S'], 'cutoff': '2655'}
#
#
# {'painel': '01af478e6df618366acb38493882044d', 'analysis': ['78V<sub>2</sub>', '96ES<sub>2</sub>', '96EV', '96Q', '98KN', '71A', '70QT', '31I', '30G', '28H', '25Q<sub>3</sub>', '181M', '180VMP', '142M<sub>3</sub>', '13FEL', '13FE', '37S', '70QA', '70QRA', '4Q'], 'cutoff': '10620'}
#
#
# {'painel': '01f2e4291ed0ca37fa89c2ce4e6420e3', 'analysis': ['145RT', '145KHA', '107W', '114Q', '114R', '144K', '138MI+79GT', '144KR', '144KR+127K', '144KR+151H', '144TKH', '149AH', '145HT', '131S+163T', '103M', '149TAH', '150AAH', '66NM', '66NV', '69AA', '69AA+76E', '70IAQ', '71ATD', '71QS', '71SA', '66NH', '66N', '66IF+163TEW', '62QE', '62QE+56G', '62RN', '62RR', '63NI', '65RA', '65RK', '65RNA', '65RNA+80I', '66IF', '66IY', '62LQ', '73ID', '76ANT', '95V', '97I', '97T', '97V', '9T', '76EG', '76ESI', '76VDT', '77NGT', '79GT', '79GT+90D', '80I+69TNT', '62GRN', '62GK', '62GE', '163R', '163RG', '163RW', '170RH', '162DLS', '177DT', '161D', '150AH', '151AHA', '151AHE', '151AHV', '151H', '152HA', '152RR', '152W', '158T', '17S', '275EL', '2I', '30G', '43Q+62GE', '44KM', '44RT', '44RT+69TNT', '56E', '56R', '245V', '184A', '186R', '193AV', '207S', '245AS', '102H'], 'cutoff': '1043'}
#
#
# {'painel': '0236a28b322b7c773d034186b0d05c69', 'analysis': ['142M<sub>3</sub>', '13SEY', '13FEL', '13FE', '85VA', '85VY', '87F', '26Y', '30H', '125G', '98Q', '96Y<sub>2</sub>', '96EV', '96ES<sub>2</sub>', '77N', '41RA<sub>2</sub>', '67VG', '55RPD', '52SK<sub>5</sub>', '52PQ<sub>2</sub>', '74R', '77N+85VG', '37S', '37N', '37FL<sub>2</sub>', '30G', '28H', '28EY', '51R<sub>2</sub>', '56E<sup>DR11</sup>', '71K', '71E', '71A', '70QT', '70QRA', '56EE<sup>DR11</sup>', '70QK', '70QQ', '70QA', '70Q', '70DK', '58EE<sup>DP</sup>', '57DE<sup>DP</sup>', '57DE'], 'cutoff': '10059'}
#
#
# {'painel': '029dd2d0869fd1eef083c3c766e8ff68', 'analysis': ['25Q<sub>3</sub>', '35LV', '47QL<sub>5</sub>', '45GE<sub>3</sub>', '45EV', '160S', '160D', '160AE', '135G', '125SQ', '98E', '96Y<sub>2</sub>', '78V<sub>2</sub>', '55PP', '55PPD', '33EYA', '11L', '75S<sub>3</sub>', '56PA', '55PPA', '13FEY', '55EA', '57D', '65LE', '76I', '76V', '84DEAV', '9H', '9YL', '70QKA', '70QE'], 'cutoff': '1240'}
#
#
# {'painel': '02a73f9cceff31ecffcedd93e847c805', 'analysis': ['44KM', '56R', '2I', '275EL', '245TA', '62QE', '62QE+56G', '143S+76ESN', '102H', '163RW', '177DK', '145RT', '17S', '152HA', '151AHA', '97N', '163RG', '152W', '163R', '71ATD', '76EG', '76ESI'], 'cutoff': '1118'}
#
#
# {'painel': '02b94e5c22ab742d113b90b15de80d21', 'analysis': ['112Y', '11STS', '149H', '16Y', '28EY', '58EE<sup>DP</sup>', '57DE<sup>DP</sup>', '57DE', '57A', '56EE<sup>DR11</sup>', '56E<sup>DR11</sup>', '135G', '70DK', '74L', '96HK', '37L', '23L', '66IT', '40GR<sub>3</sub>', '45EV', '45GE<sub>3</sub>', '55RL<sub>3</sub>'], 'cutoff': '11406'}
#
#
# {'painel': '02c75b78634c474a7d0e0ce5614936b3', 'analysis': ['96QK<sub>2</sub>', '96Y<sub>2</sub>', '74SR<sub>3</sub>', '98KN', '56PV', '66DR', '67VG', '70GT', '77R', '85VA', '85VY', '86G<sub>2</sub>', '56PS', '87F', '56PA', '55RPD', '55PPA', '125G', '125SQ', '135G', '140A<sub>2</sub>', '160D', '23L', '26L', '30H', '37YV', '3P<sub>4</sub>', '40ERV', '41KA<sub>2</sub>', '41RA<sub>2</sub>', '45GE<sub>3</sub>', '47KHL', '52PQ<sub>2</sub>', '52SK<sub>5</sub>', '98E', '96EV', '70QE', '37FV', '37FL<sub>2</sub>', '37F', '31I', '30G', '28H', '28DHF', '37L', '26L', '181M', '180VMP', '142M<sub>3</sub>', '13FEL', '13FE', '120N', '96ES<sub>2</sub>', '38L', '85A', '78V<sub>2</sub>', '74E', '71A', '70RE', '70R', '37S', '70QT', '70QKA', '70QA', '57V', '57A', '4Q', '70QRA', '47QL<sub>5</sub>', '112Y'], 'cutoff': '10216'}
#
#
# {'painel': '039ad3ba5f8dad7097e895fd06509421', 'analysis': ['75S<sub>3</sub>', '160AE', '160S', '98Q', '13SEF', '13SE', '11STS', '40YD<sub>2</sub>', '37FV', '28EH', '28EY', '31FH', '16Y', '149H', '71E', '73G', '73GQ', '74R', '77N', '37F', '32H', '96HK'], 'cutoff': '10787'}
#
#
# {'painel': '0496f9b544243ec5dff64344d1477858', 'analysis': ['9F', '86G<sub>2</sub>', '96EN<sub>3</sub>', '96ES<sub>2</sub>', '96EV', '125G', '135G', '140A<sub>2</sub>', '23L', '30H', '37YV', '3P<sub>4</sub>', '41KA<sub>2</sub>', '45GE<sub>3</sub>', '37S', '40YD<sub>2</sub>', '6C<sub>2</sub>', '71A', '87F', '52PQ<sub>2</sub>', '52PR', '142M<sub>3</sub>', '13FEY', '13FEL', '13FE', '108T', '85VA', '85VY', '28DHF', '77R', '28H', '55RL<sub>3</sub>', '55RPD', '56PS', '56PV', '66D', '66DR', '70GT', '74SR<sub>3</sub>', '74SV<sub>2</sub>', '37D<sub>2</sub>', '75V', '30G', '67VG'], 'cutoff': '1361'}
#
#
# {'painel': '050a4fc616cfb269fdb19b524fa1d895', 'analysis': ['82LR+145R', '97N', '80I', '80I+69TNT', '80I+90A', '80TA', '80TLR', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145RA', '82LR+90A', '199V', '81ALR', '144QL', '144KR+127K', '65GK', '65RNA+80I', '66IF', '66IF+163TEW', '162GLS', '163LG', '163LW+65QIT', '158T', '131S+163T', '76EN', '71ATD', '71SA', '76ESI', '71TD', '76ED', '71TN', '30G', '44RMA', '44RT', '44RT+69TNT'], 'cutoff': '1184'}
#
#
# {'painel': '067ce037cf28149742df8c20014ad0ac', 'analysis': ['77R', '75S<sub>3</sub>', '11STS', '13SE', '13SEF', '149H', '16Y', '74SR<sub>3</sub>', '56E', '56E<sup>DR11</sup>', '56EE', '56EE<sup>DR11</sup>', '57D', '57DE<sup>DP</sup>', '65LK', '58EE<sup>DP</sup>', '98Q', '96HK', '96H', '78V<sub>2</sub>', '77N+85VG', '77N', '74R', '125SQ', '73G', '73GQ', '57V', '135G', '66DR', '56PS', '45GE<sub>3</sub>', '160AE', '3P<sub>4</sub>', '37YV', '160S', '28EY', '28EH', '37F', '26Y', '9H', '31FH', '37FV'], 'cutoff': '1025'}
#
#
# {'painel': '069c820436af4faa33e9a5457022a631', 'analysis': ['145KHA', '149TAH', '107W', '144TKH', '138MI+79GT', '102H', '114R', '114Q', '79GT', '79GT+90D', '151AHE', '65RK', '66NH', '66NV', '44KM', '56E', '56R', '62LQ', '62QE', '62QE+56G', '2I', '97I', '95V', '77NGT', '71QS', '73ID', '76ANT', '76EG', '76ESI', '76VDT', '9T', '275EL', '163RW', '163RG', '163R', '151AHA', '152RR', '152HA', '161D', '17S', '245AS', '207S', '184A', '186R', '193AV'], 'cutoff': '1190'}
#
#
# {'painel': '0713392a9199de35326f8cd95b68d47c', 'analysis': ['163LS/G', '151AHV', '145RT', '145KHA', '166ES', '144TKH', '147L', '163RG', '24T', '76ESI', '76ED', '73ID', '71TD', '71SA', '71KA', '71ATD', '80TA', '102H', '103M', '144KR+127K', '107W', '143S+76ESN', '143S', '80TLR', '9T', '9H', '99S', '97N', '95V', '114Q', '66IS', '245V', '245TA', '245AS', '193PL', '186R', '184R', '184A', '193AV', '253Q', '267QE', '65RNA+80I', '65RK', '62RR', '62LQ', '62GE', '45KE', '44RMA', '41T', '32L', '30G', '2I', '270C'], 'cutoff': '1402'}
#
#
# {'painel': '07d08647c9de67da8df69aa9881c53fa', 'analysis': ['9T', '177DT', '177DK', '166ES', '166DG', '163RG', '163LW+65QIT', '163LS/G', '162GLS', '162DLS', '180E', '245TA', '161D', '21H', '158T', '143S', '131S+163T', '116L', '113HN', '102H', '143S+76ESN', '156DA', '152W', '14W', '144QL', '30G', '76ESN', '76ESI', '76ES', '73ID', '73AN', '71TTS', '2I', '80I+69TNT', '80K', '80K+14R', '97S', '71TN', '97M', '94I', '91R', '82LR+138M', '80TA', '71TD', '70IAQ', '62EE', '56E', '44RT+69TNT', '41T', '45KE', '69TNT', '69TNT+80N', '66IY', '66IS', '66IF', '65QIA+76ESN', '65GK'], 'cutoff': '11970'}
#
#
# {'painel': '08e55af17e5949dfcbcdff2f8583c9af', 'analysis': ['26Y', '181M', '140TV', '189S', '9H', '31FH', '31FYY', '84QL<sub>3</sub>', '76L', '75S<sub>3</sub>', '75IL', '66IT', '66IL', '61FT<sub>4</sub>', '56PA', '55RL<sub>3</sub>', '55PPD', '55PPA', '55PP', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '47KHL', '45GE<sub>3</sub>', '45EV', '104AK', '13SE', '13SEF', '149H', '35LV', '40ERV', '74E', '4Q', '37FV', '73G', '71K', '70RE', '70R', '70QRA', '57V', '70QK', '40GR<sub>3</sub>', '32H', '23L', '185I', '175E', '77N', '160D', '160AE', '37F', '160S', '37YV', '37Y', '96H', '96HK', '96Y<sub>2</sub>', '98E', '11STS', '38A'], 'cutoff': '12851'}
#
#
# {'painel': '0939abe041ed340c57cbefd947740625', 'analysis': ['30G', '28H', '28DHF', '180VMP', '16Y', '142M<sub>3</sub>', '26L', '37S', '71A', '96ES<sub>2</sub>', '96EV', '125SQ', '160S', '23L', '3P<sub>4</sub>', '41KA<sub>2</sub>', '85A', '78V<sub>2</sub>', '67F', '67I', '70D', '70DA', '70DR', '70DRA', '71E', '57D', '65LK', '58EE<sup>DP</sup>', '57DE<sup>DP</sup>', '56EE<sup>DR11</sup>', '56EE', '56E<sup>DR11</sup>', '56E', '13FE', '9H', '13FEL'], 'cutoff': '11572'}
#
#
# {'painel': '09947301fe82671b157f39589e7c0c88', 'analysis': ['75S<sub>3</sub>', '66IT', '45GE<sub>3</sub>', '73GQ', '74R', '77N', '40GR<sub>3</sub>', '96EN<sub>3</sub>', '96ES<sub>2</sub>', '96EV', '96H', '96HK', '98KS', '98Q', '160AE', '160S', '23L', '135G', '85A', '77N+85VG', '78V<sub>2</sub>', '55RL<sub>3</sub>', '30G', '30H', '31FH', '31FYN', '37D<sub>2</sub>', '37F', '28H', '37FV', '37N', '37S', '38L', '28EY', '28EH', '108T', '11STS', '120S', '13FEY', '13SE', '13SEF', '142M<sub>3</sub>', '149H', '16Y', '180VTP', '26Y', '28DHF', '47F', '70QQ', '71A', '73G', '71E', '70DR', '57V', '67F', '70DRA', '6C<sub>2</sub>', '70D', '70DA', '67I'], 'cutoff': '1025'}
#
#
# {'painel': '0a2710ab8f5c296ad7768a6c465acf2f', 'analysis': ['74EL', '70RT', '67VT', '67VG', '66EV', '66ER', '46VY<sub>3</sub>', '55RPD', '55PPD', '52SK<sub>5</sub>', '52PR', '55PP', '56PD', '52PQ<sub>2</sub>', '55PPA', '52PL<sub>3</sub>', '45EV', '85A', '96ES<sub>2</sub>', '96EV', '96HK', '96Y<sub>2</sub>', '98KS', '98Q', '125G', '160AE', '45GV', '167H<sub>2</sub>', '185I', '30H', '30Y', '37YA', '41RA<sub>2</sub>', '74SV<sub>2</sub>', '25RF', '77T', '31FH', '31FYY', '32H', '37N', '37S', '37YV', '30H', '38L', '47F', '4R', '57S', '30G', '28H', '28EY', '25R', '181T', '180VTP', '16Y', '149H', '142M<sub>3</sub>', '140TV', '13SEF', '13SE', '13FEL', '13FE', '26Y', '11STS', '28D', '28DY', '28EH', '75S<sub>3</sub>', '67F', '70DA', '9F', '87F', '85VY', '85VA', '70DRA', '70Q', '70QA', '70QK', '70QRA', '70QT', '71A', '71E', '71K', '74A', '74R', '77N+85VG', '26L', '77N'], 'cutoff': '11583'}
#
#
# {'painel': '0b0b863da61a2da5949df2cafebe797a', 'analysis': ['55PPA', '11L', '11M', '33EYA', '35LV', '55EA', '96Q', '96EV', '96EN<sub>3</sub>', '57A', '6C<sub>2</sub>', '108T', '96QK<sub>2</sub>', '96Y<sub>2</sub>', '98E', '47KHL', '47QL<sub>5</sub>', '98KN', '125SQ', '135G', '55RL<sub>3</sub>', '56PA', '175E', '185I', '23L', '66IT', '75IL', '96ES<sub>2</sub>', '4Q', '37S', '31I', '30G', '28H', '9YL', '181M', '180VMP', '142M<sub>3</sub>', '13FEL', '13FE', '133RS', '120N', '112Y', '37D<sub>2</sub>', '9H', '40ERV', '74E', '71A', '70RE', '70R', '57D', '45GE<sub>3</sub>', '65LE', '84DEAV', '76V', '76I'], 'cutoff': '1036'}
#
#
# {'painel': '0b18935a02013268dd3a0c435804f4b6', 'analysis': ['66IF+163TEW', '177DT', '30G'], 'cutoff': '3278'}
#
#
# {'painel': '0b4e2e2d65674632551bc4b7b8a171e3', 'analysis': ['97S', '95V', '145KHA', '151AHA', '151AHV', '158T', '144TKH', '170RH', '186R', '180E', '103M', '107W', '127K', '144KR+127K', '66KH', '66KA', '66IY', '66IF+163TEW', '65RK', '65QIA+76ESN', '70IAQ', '69TNT+80N', '63NI', '65GK', '76ESN', '71TTS'], 'cutoff': '1004'}
#
#
# {'painel': '0c03ea14e7ddd7364ecde4a5c3826af2', 'analysis': ['62GRN', '62GK', '62GE', '56E', '44RT+69TNT', '44RT', '275G', '44KM', '43Q+62GE', '35Q', '2I', '62LQ', '184A', '177KT', '163RW', '163RG', '163R', '163LW+65QIT', '163LW', '245V', '245AS', '193AV', '207S', '151AHA', '152A', '152HA', '9T', '99S', '149TAH', '145RT', '145KHA', '107W', '114Q', '97V', '138K', '144TKH', '145HT', '66NM', '66NH', '65RNA+80I', '65RK', '65QKR+76VS', '62RR', '95V', '90D', '79GT+90D', '71SA', '76VS', '76ESI', '76ANT', '73TVS', '76VRN'], 'cutoff': '11006'}
#
#
# {'painel': '0c6862d25b0352da3af93a0194afd40a', 'analysis': ['245V', '193LV', '17S', '144KR+127K', '138K', '127K', '107W', '144TKH', '145HT', '152W', '151AHV', '145KHA', '76EG', '95V', '43Q+62GE', '56R', '62GK', '65GK', '66KH'], 'cutoff': '2090'}
#
#
# {'painel': '0c9c10a5577ad446d18da14540de9c84', 'analysis': ['57A', '70QKA', '70QE', '40ERV', '40GR<sub>3</sub>', '45EV', '45GE<sub>3</sub>', '47KHL', '47QL<sub>5</sub>', '52PL<sub>3</sub>', '55PP', '55PPD', '55RL<sub>3</sub>', '56PA', '23L', '61FT<sub>4</sub>', '185I', '57D', '96QK<sub>2</sub>', '96Y<sub>2</sub>', '135G', '112Y', '175E', '66IL', '33EYA', '35LV', '55EA', '66IT', '75IL', '76L', '84QL<sub>3</sub>', '11L', '11M', '65LE', '9YL', '9H', '76I', '76V', '84DEAV'], 'cutoff': '15528'}
#
#
# {'painel': '0d10e29d75af6551e75c87d10169a1d2', 'analysis': ['11L', '86G<sub>2</sub>', '57D', '33EYA', '9H', '9YL', '55RL<sub>3</sub>', '55PPA', '65LE', '76I', '84DEAV', '76V', '48Q<sub>6</sub>', '4Q', '57A', '112Y', '13FEY', '25Q<sub>3</sub>', '70QE', '51R<sub>2</sub>', '41KA<sub>2</sub>', '160D', '70QKA', '185I', '3P<sub>4</sub>', '70RE', '74E', '78V<sub>2</sub>', '96Y<sub>2</sub>', '98E'], 'cutoff': '1171'}
#
#
# {'painel': '0da9d9df808fd618e7ccf1566fc3b10b', 'analysis': ['66IF', '66IC', '66IF+163TEW', '66IY', '65QIA+76ESN', '63NI', '44RT', '62GK', '56E', '45KE', '45EE', '44RT+69TNT', '69AA+65QI', '70IAQ', '80I+69TNT', '43Q+62GE', '71TN', '71TD', '71KA', '71ATD', '76ED', '156DA', '177DK', '177DT', '180E', '245V', '248M', '170RH', '166ES', '41T', '32L', '158T', '162GLS', '163EW+66I', '163EW+73TE', '163LS/G', '80TA', '145KHA', '144TKH', '24T', '116L', '107W', '9H', '131S+163T', '95V', '97N', '97S', '97T', '80TLR'], 'cutoff': '10798'}
#
#
# {'painel': '0db91ddf843ce48691c0d65952c573a9', 'analysis': ['80I+90A', '80TA', '80TLR', '81ALR', '82LR', '66K', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A', '91R', '95V', '97N', '80I+69TNT', '71TN', '71TD', '71SA', '65RNA+80I', '71ATD', '80I', '66IF+163TEW', '65RK', '66KH', '76ED', '66KA', '76ESI', '151AHV', '163LG', '156WA', '14W', '107W', '114H', '116Y', '127K', '131S+163T', '144QL', '144TKH', '145KHA', '62GE', '62RR', '44RMA', '173K', '177DT', '184A', '186R', '199V'], 'cutoff': '111'}
#
#
# {'painel': '0dfaab7bd101edb0c413798f4d19e9a1', 'analysis': ['44RT+69TNT', '44RT', '107W', '66IF', '80I+69TNT', '66IC', '65RNA+80I', '14W', '62EE', '71TD', '71SA', '103M', '71KA', '71TN', '71ATD', '73AN', '62GE', '66KH', '44RMA', '82LR', '193PL', '184R', '80I+90A', '66IF+163TEW', '81ALR', '80TLR', '43Q+62GE', '76ESI', '80TA', '65GK', '102H', '166DG', '166ES', '16S', '76ED', '199V', '211T', '82LR+90A', '270C', '95V', '267QE', '144QL', '97N', '163LW+65QIT', '62GRN', '163LS/G', '162GLS', '158T', '82LR+138T', '62GK', '82LR+138M', '82LR+144QR', '162DLS', '82LR+145R', '275K', '99S', '9D', '82LR+145RA'], 'cutoff': '1069'}
#
#
# {'painel': '0e814ec67c3bd9f21a360e7bf8ce3a49', 'analysis': ['97I', '97V', '62GE', '9T', '62QE', '56E', '62GRN', '62GK', '62QE+56G', '71SA', '71QS', '66NV', '66NM', '65RNA+80I', '65RNA', '65RK', '65RA', '66NH', '79GT+90D', '79GT', '77NGT', '76VDT', '76ESI', '76ANT', '44KM', '152RR', '152HA', '151AHV', '151AHE', '150AH', '150AAH', '149TAH', '149AH', '151H', '145RT', '43Q+62GE', '193AV', '184A', '163RW', '163RG', '163R', '145KHA', '144TKH', '207S', '245AS', '62RR', '275EL', '2I', '145HT', '144KR+127K', '144KR', '144K', '138MI+79GT', '144KR+151H', '114R', '114Q', '107W'], 'cutoff': '10895'}
#
#
# {'painel': '0e8ac95b6303f8241cd3fa6b69e7d354', 'analysis': ['77D', '76ET', '76VRN', '76VS', '76ANT', '76VDT', '71QS', '73AN', '71TD', '71SA', '70IAQ', '77NGT', '73TVS', '79GT', '99S', '69RT', '9T', '9F', '9D', '97S', '97I', '95W', '95V', '90D', '80TLR', '80TL', '80TA', '80T', '80K+14R', '80K', '79GT+90D', '69RA', '65RNA', '69AA+65QI', '156DA', '162GLS', '163EW', '163EW+66I', '163EW+73TE', '163LS/G', '163R', '163RW', '166ES', '16S', '177DK', '177DT', '177KT', '163LG', '180E', '152HA', '152A', '107W', '113YN', '114Q', '114R', '116D', '11AV', '138K', '143S', '144QL', '144TKH', '145KHA', '145RT', '147L', '149TAH', '14W', '151AHE', '138MI+79GT', '184A', '184H', '184R', '62GE', '62GRN', '62QE', '62QE+56G', '62RR', '65QIA', '65QIA+76ESN', '65QKR', '65RA', '65RK', '65RNA+80I', '66IF+163TEW', '66IY', '66N', '66NH', '66NM', '66NV', '69AA', '65QKR+76VS', '193AV', '193LV', '199V', '1C', '207S', '211T', '219W', '21H', '245AS', '24T', '253Q', '267QE', '270C', '275EL', '275G', '275K', '32L', '35Q', '41T', '69AA+76E', '163E'], 'cutoff': '10649'}
#
#
# {'painel': '0eeeb93c5d2e9dfbbde6bedd91a2d6d4', 'analysis': ['114Q', '186R', '107W', '193AV', '245AS', '143S+76ESN', '144TKH', '161D', '158T', '151AHE', '149TAH', '145RT', '145KHA', '144QL', '62GK', '62LQ', '65QIA', '65QIA+76ESN', '65RK', '69AA+65QI', '71QS', '43Q+62GE', '9T', '97S', '163EW+66I', '95V', '80TA', '76VDT', '76ESI', '73ID', '163EW+73TE', '70IAQ', '163RW', '163LS/G', '166ES', '177DT', '180E', '184A', '177DK'], 'cutoff': '11350'}
#
#
# {'painel': '0f116fa2ac3abf17e1d125df6d5f20c2', 'analysis': ['37L', '23L', '108T', '31FYN', '142M<sub>3</sub>', '16Y', '25Q<sub>3</sub>', '28DHF', '71E', '47F', '56E<sup>DR11</sup>', '57DE', '57DE<sup>DP</sup>', '58EE<sup>DP</sup>', '67I', '6C<sub>2</sub>', '70D', '70DA', '70DR', '70DRA', '56EE<sup>DR11</sup>', '75S<sub>3</sub>', '55RL<sub>3</sub>', '71A', '96EN<sub>3</sub>', '160S', '160AE'], 'cutoff': '10126'}
#
#
# {'painel': '0f16930fdf163ddda05a00bbbc12bcda', 'analysis': ['80K+14R', '80K', '66KH', '62GK', '145HT', '56E', '43Q+62GE', '44KM', '62EE'], 'cutoff': '1350'}
#
#
# {'painel': '0f52f3cd4bababa358dc843dc148ebfb', 'analysis': ['71E', '125G', '41RA<sub>2</sub>', '30H', '51R<sub>2</sub>', '40YD<sub>2</sub>', '37D<sub>2</sub>', '52PQ<sub>2</sub>', '52PR', '85VY', '85VA', '74SV<sub>2</sub>', '67VG', '55RPD', '55RL<sub>3</sub>', '52SK<sub>5</sub>', '87F', '9F'], 'cutoff': '12441'}
#
#
# {'painel': '0f56b6e11f8fb3d2c7b9e2b5197ffcbf', 'analysis': ['65RNA+80I', '66IF+163TEW', '66KH', '71ATD', '65GK', '2I', '43Q+62GE', '56E', '62EE', '62GE', '62GK', '71TD', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A', '82LR+138M', '71SA', '82LR', '80TLR', '71TN', '76ED', '76ESI', '80I', '80I+69TNT', '80I+90A', '81ALR', '161D', '162GLS', '163LG', '163RG', '166DG', '144KR+127K', '144QL', '145HT', '199V'], 'cutoff': '1214'}
#
#
# {'painel': '0fc22016cb480c0615bb61ca4dd2fefe', 'analysis': ['33EYA', '35LV', '55A', '55EA', '35YA', '56A', '85VA', '11L', '11M', '65LE', '69R<sub>2</sub>', '76I', '76V', '57D', '84DEAV', '9YL', '9H', '77R', '66DR', '67VG', '52PQ<sub>2</sub>', '52SK<sub>5</sub>', '56PA', '45GE<sub>3</sub>', '78V<sub>2</sub>', '71A', '41RA<sub>2</sub>', '96ES<sub>2</sub>', '26L', '160D', '140A<sub>2</sub>', '125G', '98KN', '96QK<sub>2</sub>', '96Q', '96EV', '135G', '28H', '30G', '31I', '37S', '48Q<sub>6</sub>', '4Q', '25Q<sub>3</sub>', '133RS', '13FE', '13FEL', '142M<sub>3</sub>', '180VMP', '181M'], 'cutoff': '10153'}
#
#
# {'painel': '0fd7286752e444b136f1528da343462e', 'analysis': ['98KN', '98E', '96QK<sub>2</sub>', '57S', '4Q', '37YV', '70QA', '96Q', '96EV', '96EN<sub>3</sub>', '74E', '96Y<sub>2</sub>', '71A', '70RE', '70R', '70QT', '70QRA', '47QL<sub>5</sub>', '35LV', '37S', '160D', '185I', '23L', '45EV', '52PL<sub>3</sub>', '55PPA', '55PPD', '55RL<sub>3</sub>', '55PP', '120N', '13FE', '13FEL', '142M<sub>3</sub>', '180VMP', '181M', '28H', '37D<sub>2</sub>', '108T', '32YN', '31I', '32Y', '31FYN', '31FY', '31FYY'], 'cutoff': '10924'}
#
#
# {'painel': '10adef4b7dfd2e5b2098a403f71427fb', 'analysis': ['163LG', '163LE', '163L', '162DLS', '163LS/G', '158T', '163LW', '71SA', '166ES', '163LW+65QIT', '12M', '102H', '107W', '151AHV', '127K', '144QL', '144TKH', '145KHA', '145RT', '149TAH', '95V', '95W', '97T', '9T', '69TNT+80N', '66KH', '66KA', '81ALR', '71TN', '71TTS', '73ID', '80I', '80I+69TNT', '80I+90A', '80TA', '82LR+138M', '66IF+163TEW', '199V', '66IF', '30G', '65RNA+80I', '65RK', '62RR', '62LQ', '62GE', '45KE', '44RMA', '41T'], 'cutoff': '10557'}
#
#
# {'painel': '10f3c3287e76aa9b45145f7368f551e5', 'analysis': ['13FEL', '9F', '37S', '87F', '85VY', '85VA', '13SEY', '142M<sub>3</sub>', '180VMP', '25Q<sub>3</sub>', '28DHF', '28H', '30G', '37FL<sub>2</sub>', '26Y', '74SV<sub>2</sub>', '125G', '96EV', '96ES<sub>2</sub>', '78V<sub>2</sub>', '74R', '71A', '70QKA', '70QE', '23L', '67VG', '55RPD', '55RL<sub>3</sub>', '52SK<sub>5</sub>', '52PQ<sub>2</sub>', '52PR', '3P<sub>4</sub>', '30H', '41RA<sub>2</sub>', '13FE'], 'cutoff': '10435'}
#
#
# {'painel': '11f920aaf904c22bd9376d89ffd5519d', 'analysis': ['107W', '114Q', '77NGT', '9T', '62GE', '56R', '44RT+69TNT', '44RT', '43Q+62GE', '30G', '62GK', '245AS', '207S', '193AV', '253Q', '62GRN', '76EG', '76ANT', '66NH', '65RK', '184A', '17S', '145RT', '145KHA', '144TKH', '144KR+127K', '79GT+90D', '80K+14R', '149TAH', '95V', '97V', '99S', '163RW', '151AHV', '163R', '152W', '152RR', '152HA'], 'cutoff': '10300'}
#
#
# {'painel': '1235e572dd827cff7d31e954b3f94489', 'analysis': [], 'cutoff': '0'}
#
#
# {'painel': '126c07e4b90561b75028f9b39dd95a2d', 'analysis': ['193PL', '245AS', '211T', '186R', '144KR', '114R', '144KR+151H', '145RT', '14W', '152HA', '184R', '114Q', '16S', '166ES', '166DG', '163RW', '163RG', '163R', '163LS/G', '162GLS', '162DLS', '102H', '163LG', '245V', '76ESI', '76ANT', '73ID', '73AS', '73AN', '71QS', '71ATD', '70IAQ', '62LQ', '69RA', '65QIA+76ESN', '62QE+56G', '65GK', '62RR', '79GT+90D', '2I', '44KM', '62EE', '152W', '9T', '9D', '91R', '82LR+138M', '97M', '97N'], 'cutoff': '1183'}
#
#
# {'painel': '12900d726270163786187fd459682b64', 'analysis': ['74L', '125G', '160D', '185I', '67VG', '52SK<sub>5</sub>', '52PR', '52PQ<sub>2</sub>', '45GV', '41RA<sub>2</sub>', '74SV<sub>2</sub>', '85VA', '9F'], 'cutoff': '11677'}
#
#
# {'painel': '12b58d86b26b2dc0adfdfd9287e33dfb', 'analysis': ['149Q', '140AV', '142M<sub>3</sub>', '140A', '13SE', '104A', '13FEL', '13FE', '133RS', '120N', '11STS', '112Y', '108T', '104AK', '16H', '180VMP', '30G', '189R', '37S', '37N', '37L', '37FV', '37F', '37D<sub>2</sub>', '32H', '181M', '31I', '30H', '28EY', '28EH', '28E', '28DHF', '26Y', '26L', '31FH', '28H', '96Q', '160D', '160AE', '140A<sub>2</sub>', '13GM', '125SQ', '125G', '98Q', '98KN', '98E', '96Y<sub>2</sub>', '96QK<sub>2</sub>', '160S', '75S<sub>3</sub>', '96ES<sub>2</sub>', '96EN<sub>3</sub>', '86V', '85VV', '85A', '78V<sub>2</sub>', '77N+85VG', '77N', '74R', '74E', '74A', '73GQ', '96EV', '167R', '185I', '23L', '70GT', '67VG', '66IL', '66DR', '66D', '56PV', '56PS', '56PA', '55RPD', '55RL<sub>3</sub>', '55PPA', '52SK<sub>5</sub>', '52PR', '52PQ<sub>2</sub>', '47QL<sub>5</sub>', '47KHL', '45GV', '45GE<sub>3</sub>', '45G', '41RA<sub>2</sub>', '41KA<sub>2</sub>', '40ERV', '3P<sub>4</sub>', '37YV', '30H', '26L', '25YT', '73G', '71K', '71E', '71A', '74SR<sub>3</sub>', '77R', '85VA', '85VY', '86G<sub>2</sub>', '87F', '9F', '35LV', '96A', '9H', '38L', '40YD<sub>2</sub>', '38A', '48Q<sub>6</sub>', '70RE', '70R', '70QT', '70QRA', '70QQ', '70QK', '75V', '70QA', '70Q', '47F', '6C<sub>2</sub>', '70DK', '4Q', '56E<sup>DR11</sup>', '67L', '57A', '56EE<sup>DR11</sup>', '57DA', '57DE', '57DE<sup>DP</sup>', '57V', '58EE<sup>DP</sup>', '57D', '74SV<sub>2</sub>'], 'cutoff': '1012'}
#
#
# {'painel': '12c4a887a72589a6f4ad28ece16fe99e', 'analysis': ['11L', '33EYA', '35LV', '55EA', '57D', '65LE', '76I', '76V', '84DEAV', '9H', '9YL', '87F', '30H', '23L', '125G', '98KN', '96QK<sub>2</sub>', '96Q', '96EV', '96ES<sub>2</sub>', '78V<sub>2</sub>', '74SV<sub>2</sub>', '70GT', '67VG', '56PV', '55RPD', '55RL<sub>3</sub>', '52SK<sub>5</sub>', '52PR', '52PQ<sub>2</sub>', '41RA<sub>2</sub>', '74L', '9F', '31I', '30G', '85VY', '85VA', '13FE', '13FEL', '28H', '13FEY', '142M<sub>3</sub>', '180VMP', '181M', '133RS', '25Q<sub>3</sub>', '4Q', '67F', '37S', '48Q<sub>6</sub>', '70QE', '70QKA', '70QRA', '70QT', '71A', '70QA', '40YD<sub>2</sub>'], 'cutoff': '1015'}
#
#
# {'painel': '12ca7c75f87135a3fb9395485de22a3c', 'analysis': ['55RL<sub>3</sub>', '4Q', '38L', '37S', '133RS', '142M<sub>3</sub>', '16Y', '28DHF', '55PPD', '31FYN', '6C<sub>2</sub>', '96EV', '125G', '160D', '96ES<sub>2</sub>', '167H<sub>2</sub>', '185I', '23L', '30Y', '37YA', '45EV', '55PP', '85A', '57V', '67I', '70D', '70DA', '70DR', '71A', '71E', '70DRA', '70GT', '55EA', '50RA', '35YA', '35LV', '33EYA', '31Q', '127P<sub>2</sub>', '11M', '11L', '111R', '9F', '87F', '77T', '74EL', '70RT', '67VT', '66ER', '52PL<sub>3</sub>', '9YL', '9H', '96A', '84DEAV', '76V', '69R<sub>2</sub>', '76I', '57D', '65LE'], 'cutoff': '10879'}
#
#
# {'painel': '135bb872ccd29b4235dede2c5494128f', 'analysis': ['85VY', '9F', '87F', '85VA', '74SV<sub>2</sub>', '160S', '160AE', '125G', '30H', '67VG', '75S<sub>3</sub>', '55RPD', '55RL<sub>3</sub>', '52SK<sub>5</sub>', '52PR', '52PQ<sub>2</sub>', '41RA<sub>2</sub>'], 'cutoff': '5276'}
#
#
# {'painel': '13710b13a50b9e2464ca13086dcadcd3', 'analysis': ['184A', '177KT', '177DT', '173K', '166DG', '163RW', '163R', '163LG', '193LV', '41T', '35Q', '275G', '248M', '219W', '158T', '144KR+151H', '144KR', '144K', '138K', '131S+163T', '127K', '114R', '113YN', '102H', '116F', '144TKH', '145KHA', '156QA', '152T', '152RA', '152HA', '152A', '151H', '151AHV', '151AHE', '150AH', '150AAH', '14W', '149TAH', '149AH', '145RT', '45KE', '62EE', '73AS', '73TVS', '76ANT', '76ESI', '76VRN', '76VS', '9F', '91R', '90D', '82LR+138M', '80TA', '9D', '99S', '97W', '71TD', '79GT+90D', '71QS', '71SA', '65QKR', '65QKR+76VS', '65RK', '65RNA+80I', '65GK', '62LQ', '62QE+56G', '66IF+163TEW', '66K', '66KA', '66KH', '66NM', '62GE'], 'cutoff': '1011'}
#
#
# {'painel': '1386dab082853412c6064ab61029ffc4', 'analysis': ['186R', '180E', '17S', '193LV', '193PL', '24T', '2I', '275K', '275EL', '270C', '199V', '267QE', '245V', '245AS', '21H', '219W', '211T', '248M', '177DK', '156DA', '145RT', '147L', '14W', '151AHA', '152A', '152HA', '152RA', '152RE', '152RR', '152W', '16S', '166ES', '163RW', '163RG', '163R', '163LS/G', '173K', '163LG', '163EW+66I', '163EW', '163E', '162GLS', '162DLS', '161D', '163EW+73TE', '32L', '41T', '73ID', '76ANT', '76ED', '76EG', '76ESI', '76ET', '79GT+90D', '80TA', '80TLR', '9T', '9D', '97W', '73AN', '97N', '91R', '90D', '97I', '71TD', '65QIA+76ESN', '65QIA', '62RR', '62QE+56G', '65RNA', '62QE', '56R', '56E', '45KE', '44KM', '62LQ', '71QS', '71KA', '71ATD', '70IAQ', '69RA', '66IF+163TEW', '69AA+76E', '69AA', '66NV', '66NH', '66N', '69AA+65QI', '144QL', '77NGT', '143S', '102H', '103M', '113YD', '114Q', '116D', '116L', '138MI+79GT', '114R'], 'cutoff': '10334'}
#
#
# {'painel': '13892c77607c16c4d3af2023425f15d9', 'analysis': ['56E', '62EE', '62GK', '65GK', '95V', '43Q+62GE', '66KH', '145HT', '14W', '144KR+127K', '102H', '107W', '184R'], 'cutoff': '406'}
#
#
# {'painel': '14233c448cfec8f492468dc66ade4775', 'analysis': ['160S'], 'cutoff': '622'}
#
#
# {'painel': '14850e049ed260aaa774d50f8f0d954e', 'analysis': ['86G<sub>2</sub>', '127P<sub>2</sub>', '11L', '11M', '76L', '111R', '56PA', '70RT', '66IL', '66ER', '66DR', '66D', '61FT<sub>4</sub>', '56PV', '75IL', '31Q', '9YL', '35LV', '55RL<sub>3</sub>', '9H', '96A', '84DEAV', '33EYA', '76I', '69R<sub>2</sub>', '65LE', '57D', '55EA', '50RA', '35YA', '76V', '55PPD', '40ERV', '74L', '74E', '37F', '37FV', '4Q', '57V', '70QE', '70R', '70RE', '78V<sub>2</sub>', '96QK<sub>2</sub>', '16Y', '180VMP', '181M', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '47KHL', '45GE<sub>3</sub>', '45EV', '55PP', '40GR<sub>3</sub>', '185I', '175E', '167H<sub>2</sub>', '125SQ', '3P<sub>4</sub>'], 'cutoff': '12110'}
#
#
# {'painel': '154ccf6d0bb9b080dc17a315ebc7d097', 'analysis': ['75S<sub>3</sub>', '74R', '13SEY', '48Q<sub>6</sub>', '45EV', '55PPA', '55PPD', '45GE<sub>3</sub>', '55PP', '160S', '37FL<sub>2</sub>', '135G', '56PA', '160AE'], 'cutoff': '1737'}
#
#
# {'painel': '164d502b94312ca23c5a9ab9d3a0c868', 'analysis': ['66KH', '65GK', '62GK', '145HT', '163LG', '144KR+127K', '30G', '43Q+62GE'], 'cutoff': '451'}
#
#
# {'painel': '1652d1c5a9f21a26d7ea7b3569daf7e2', 'analysis': ['28DHF', '66DR', '66D', '26L', '61FT<sub>4</sub>', '56PA', '55RL<sub>3</sub>', '30Y', '37YA', '55PPD', '3P<sub>4</sub>', '40ERV', '47KHL', '55PP', '40GR<sub>3</sub>', '41KA<sub>2</sub>', '45EV', '45GE<sub>3</sub>', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '25FT', '66ER', '66IL', '66IT', '75S<sub>3</sub>', '116V', '129H', '135G', '160D', '167H<sub>2</sub>', '175E', '185I', '23L', '70RT', '67VT', '13GM', '96Y<sub>2</sub>', '75IL', '74EL', '57D', '65LE', '77T', '84QL<sub>3</sub>', '86G<sub>2</sub>'], 'cutoff': '13004'}
#
#
# {'painel': '167dc5d3159de8e9401c1c0dc9b55c2a', 'analysis': ['14W', '149AH', '103M', '107W', '144TKH', '144QL', '127K', '143S+76ESN', '144K', '114H', '177DK', '166ES', '163LS/G', '163LG', '163EW+73TE', '71TD', '163EW+66I', '162GLS', '162DLS', '158T', '156DA', '152W', '151AHV', '71KA', '180E', '17S', '177DT', '45KE', '66KH', '66NH', '193PL', '199V', '41T', '66IF+163TEW', '32L', '145KHA', '24T', '82LR+138M', '95V', '97S', '99S', '80TLR', '71HS', '76EG', '56R', '80TA', '76ED', '76ET'], 'cutoff': '10542'}
#
#
# {'painel': '16eeaeda941a2925e34dc95a216b6538', 'analysis': ['75S<sub>3</sub>', '66IT', '70QKA', '55RL<sub>3</sub>', '71K', '77N', '77N+85VG', '96HK', '96Y<sub>2</sub>', '98Q', '160AE', '160D', '71E', '160S', '185I', '40GR<sub>3</sub>', '45EV', '70QQ', '52PL<sub>3</sub>', '55PP', '55PPA', '55PPD', '57S', '70DA', '70QK', '70QE', '70DRA', '28DHF', '28D', '16Y', '149H', '142M<sub>3</sub>', '13SEY', '13SEF', '13SE', '11STS', '28DY', '28EH', '74R', '31FYY', '37YV', '38L', '47F', '51R<sub>2</sub>', '31FH', '30H', '28EY'], 'cutoff': '10109'}
#
#
# {'painel': '17afb33ceb04c1daf08749a6146daad6', 'analysis': ['24S', '248M', '21H', '219W', '211T', '163LS/G', '163R', '163RW', '166DG', '166ES', '16S', '170RH', '177DK', '1C', '177KT', '17S', '180E', '184H', '184R', '186R', '193LV', '163EW+73TE', '163EW+66I', '151AHV', '151AHE', '150AH', '150AAH', '14W', '149TAH', '151H', '149AH', '145RT', '145KHA', '144TKH', '144KR+151H', '147L', '24T', '152A', '152HA', '163EW', '163E', '158T', '156WA', '152E', '156RA', '156QA', '156DA', '152W', '152T', '152RR', '152RE', '152RA', '156R', '267QE', '35Q', '275EL', '80TA', '80K+14R', '80K', '80I+69TNT', '79GT+90D', '76VS', '80TLR', '76VRN', '76EG', '73TVS', '73AS', '73AN', '76ET', '71TN', '82LR+138M', '9S', '9H', '9F', '9D', '99S', '99F', '90D', '97W', '97S', '97I', '95W', '95V', '95L', '97T', '62EE', '45KE', '45EE', '62QE+56G', '144K', '32L', '275K', '275G', '41T', '62RR', '65QIA', '70IAQ', '69RT', '69RA', '69AA+65QI', '66KH', '66KA', '66K', '66IY', '66IS', '66IC', '65RK', '65QKR+76VS', '65QKR', '65QIA+76ESN', '270C', '144KR', '143S', '102H', '103M', '107W', '113HN', '113YD', '113YN', '114H', '116L', '116F', '116Y', '11AV', '127K', '131S+163T', '138K'], 'cutoff': '1058'}
#
#
# {'painel': '17b6d6e71e8de8e14f1b1805b4a0efde', 'analysis': ['74EL', '37FV', '37F', '31FYN', '31FYY', '37Y', '75IL', '31FY', '31FH', '32H', '37YV', '40YD<sub>2</sub>', '57V', '57S', '70GT', '38A', '4Q', '48Q<sub>6</sub>', '47F', '31F', '70RT', '30Y', '13SEF', '13SE', '11STS', '84QL<sub>3</sub>', '104AK', '86G<sub>2</sub>', '87F', '9F', '140TV', '30H', '142M<sub>3</sub>', '77T', '28EY', '28DY', '76L', '28DHF', '28D', '26Y', '189S', '181M', '180VMP', '149H', '67VT', '30Y', '26L', '25FT', '23L', '185I', '175E', '37YA', '167H<sub>2</sub>', '160D', '13GM', '135G', '129H', '125G', '3P<sub>4</sub>', '66D', '40ERV', '56PA', '55RPD', '55RL<sub>3</sub>', '55PPD', '61FT<sub>4</sub>', '55PP', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '47KHL', '45GE<sub>3</sub>', '45EV', '40GR<sub>3</sub>', '116V', '98Q', '98E', '70RE', '70R', '66IL', '66IT', '70QKA', '70QK', '70QE', '56PD', '71K', '73G', '74E', '96Y<sub>2</sub>', '66DR', '96QK<sub>2</sub>', '96Q', '96HK', '96H', '77N+85VG', '77N', '66ER', '74R', '73GQ', '85VV', '56EE', '9H', '57D', '57DE<sup>DP</sup>', '58EE<sup>DP</sup>', '65LE', '65LK', '56E<sup>DR11</sup>', '56EE<sup>DR11</sup>', '56E'], 'cutoff': '10726'}
#
#
# {'painel': '184c6b3aa506b615b41b720968282a05', 'analysis': ['51R<sub>2</sub>', '56E<sup>DR11</sup>', '56EE<sup>DR11</sup>', '57DE<sup>DP</sup>', '40YD<sub>2</sub>', '58EE<sup>DP</sup>', '67F', '67I', '70D', '70DA', '57DE', '37S', '13FEL', '142M<sub>3</sub>', '180VMP', '25Q<sub>3</sub>', '26L', '28EH', '28H', '30G', '13FE', '30H', '65LE', '69R<sub>2</sub>', '76I', '76V', '84DEAV', '9H', '9YL', '70DK', '31Q', '33EYA', '35LV', '35YA', '55EA', '57D', '70DR', '31FYN', '52PR', '52SK<sub>5</sub>', '55RL<sub>3</sub>', '67VG', '74SV<sub>2</sub>', '70DRA', '11M', '11L', '85VA', '111R', '9F', '52PQ<sub>2</sub>', '135G', '125G', '96EV', '96ES<sub>2</sub>', '85A', '78V<sub>2</sub>', '71E', '41RA<sub>2</sub>', '71A'], 'cutoff': '10142'}
#
#
# {'painel': '1877b7c5882add9a9aa7287d2a9624d1', 'analysis': ['71TN', '73AN', '76EG', '73TVS', '71SA', '76EN', '76ET', '73ID', '71QS', '116L', '70IAQ', '69RT', '127K', '138K', '143S', '80I', '144TKH', '80I+69TNT', '82LR+145R', '80K', '45KE', '105S', '107W', '113YN', '114H', '9Y', '9T', '9S', '99S', '99F', '97W', '80I+90A', '97T', '95V', '94I', '82LR+90A', '82LR+145RA', '69AA+76E', '82LR+144QR', '82LR+138T', '82LR+138M', '82LR', '81ALR', '80TLR', '80TA', '80K+14R', '145KHA', '151AHE', '149TAH', '184R', '184H', '17S', '177DK', '166ES', '163RW', '163LW+65QIT', '163LW', '163LS/G', '163LE', '163L', '56E', '56R', '41T', '35Q', '44RMA', '32L', '275K', '275G', '270C', '24T', '21H', '219W', '193PV', '145RT', '62EE', '158T', '156WA', '156RA', '156QA', '152W', '152RE', '152E', '69AA+65QI', '151AHV', '151AHA', '150AH', '150AAH', '69AA', '62GE', '161D', '62RR', '65QIA', '65QIA+76ESN', '65RK', '65RNA+80I', '66IC', '66IY', '66KA', '66KH', '163EW+73TE', '163EW+66I', '163EW', '163E', '95W'], 'cutoff': '10812'}
#
#
# {'painel': '18ae3390aef2cf52c77fabe1542d1971', 'analysis': ['63NI', '62QE+56G', '62GRN', '62GE', '62EE', '79GT+90D', '80I', '80I+69TNT', '80I+90A', '80K', '80K+14R', '80TA', '80TLR', '81ALR', '156DA', '56E', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A', '65GK', '65QIA', '65QIA+76ESN', '193PV', '71TN', '71TD', '71SA', '152RE', '71KA', '71ATD', '70IAQ', '90D', '69AA+76E', '69AA', '66NM', '66KH', '66KA', '66IY', '66IF+163TEW', '66IF', '66IC', '65RNA+80I', '65RK', '69AA+65QI', '156WA', '158T', '161D', '162DLS', '162GLS', '163LG', '163LS/G', '163LW+65QIT', '163R', '163RG', '166DG', '166ES', '177DT', '184A', '184R', '193PL', '163RW', '76ED', '95V', '95W', '97N', '97T', '99S', '9D', '245V', '44RT+69TNT', '44RT', '44RMA', '44KM', '30G', '2I', '275K', '270C', '267QE', '9Y', '73AN', '144QL', '144TKH', '145KHA', '149AH', '149TAH', '144KR+151H', '14W', '150AH', '151AHA', '151AHV', '151H', '102H', '150AAH', '103L', '138K', '131S+163T', '131S', '127K', '116L', '144KR+127K', '114H', '113HD', '107W', '103M', '144K', '77N', '151AHE', '199V', '76ESI', '152E', '152HA'], 'cutoff': '103'}
#
#
# {'painel': '18ca12c754852a11ca8ffbbeeee77b76', 'analysis': ['28H', '30G', '31FYN', '55PPA', '37L', '25Q<sub>3</sub>', '16Y', '87F', '86G<sub>2</sub>', '70GT', '55RPD', '13FEY', '142M<sub>3</sub>', '70QKA', '71A', '71E', '74L', '78V<sub>2</sub>', '160S', '160D', '28D', '178M', '125G', '70DRA', '70DR', '56E<sup>DR11</sup>', '56EE<sup>DR11</sup>', '57DE', '57DE<sup>DP</sup>', '57S', '58EE<sup>DP</sup>', '41KA<sub>2</sub>', '3P<sub>4</sub>', '67I', '70D', '70DA', '70DK', '67F', '35FA', '84GGPM', '84VGPM', '96A', '96R<sub>2</sub>', '65LK', '65LE', '85GPM', '57D'], 'cutoff': '1004'}
#
#
# {'painel': '18d8a49c209e4b870507375de08b2ac3', 'analysis': ['45GE<sub>3</sub>', '47KHL', '47QL<sub>5</sub>', '52PL<sub>3</sub>', '55RL<sub>3</sub>', '55PPD', '56PA', '45EV', '55PP', '160D', '40ERV', '23L', '185I', '175E', '135G', '40GR<sub>3</sub>', '66IL', '57D', '84QL<sub>3</sub>', '76L', '75IL', '57V', '96HK', '11STS', '13SE', '13SEF', '149H', '16Y', '112Y', '26Y', '28EH', '28EY', '31FH', '37F', '96H', '77N+85VG', '77N', '74R', '73GQ', '73G', '58EE<sup>DP</sup>', '57DE<sup>DP</sup>', '57DE', '57A', '56EE<sup>DR11</sup>', '56E<sup>DR11</sup>', '37L', '37FV'], 'cutoff': '11359'}
#
#
# {'painel': '18e0085f5d92be70325bcca084e26c26', 'analysis': ['66EV', '66ER', '56PD', '55PPD', '133RS', '55PP', '52SK<sub>5</sub>', '52PQ<sub>2</sub>', '45EV', '41RA<sub>2</sub>', '13FE', '167H<sub>2</sub>', '67VT', '70RT', '85VA', '74EL', '125G', '26L', '32Y', '32YN', '28H', '30G', '70DRA', '70DR', '70DA', '70D', '67I', '67F', '57S', '4Q', '48Q<sub>6</sub>', '40YD<sub>2</sub>', '37S', '13FEL', '181M', '16Y', '98KN', '96QK<sub>2</sub>', '96Q', '96EV', '96ES<sub>2</sub>', '85A', '13FEY', '78V<sub>2</sub>', '71E', '71A', '31I', '70QKA', '142M<sub>3</sub>', '180VMP', '31FYN'], 'cutoff': '1313'}
#
#
# {'painel': '1910f51b598ae04001d51ab1585e8c90', 'analysis': ['70IAQ', '69TNT+80N', '69AA+65QI', '66KH', '66KA', '66IY', '66IF+163TEW', '66IC', '65RK', '65QKR+76VS', '65QIA+76ESN', '65QIA', '65GK', '62GK', '56R', '45EE', '71KA', '71TTS', '73AS', '9S', '9H', '99S', '97S', '95V', '80N', '77SRN', '76VS', '76VRN', '76ESN', '76EG', '76ED', '73TVS', '73ID', '43Q+62GE', '9T', '152W', '152RA', '151AHV', '151AHA', '14W', '147L', '145KHA', '144TKH', '143S+76ESN', '143S', '131S+163T', '127K', '116L', '114H', '107W', '102H', '156QA', '158T', '270C', '267QE', '248M', '21H', '211T', '193PL', '193LV', '186R', '184R', '180E', '177DT', '177DK', '173K', '16S', '163EW+73TE', '163EW+66I', '163EW', '17S'], 'cutoff': '1060'}
#
#
# {'painel': '1993c16a730b50f407bcd7acf59e66ff', 'analysis': ['65RK', '95V', '62LQ', '62GRN', '62GK', '56E', '97V', '43Q+62GE', '62GE', '79GT+90D', '76ANT', '245V', '152HA', '102H', '151AHA', '149TAH', '145RT', '145KHA', '145HT', '144TKH', '186R', '163R', '163RW', '107W'], 'cutoff': '1154'}
#
#
# {'painel': '19ad20744e4a9cbf9c04c131bf9b0ddc', 'analysis': ['37F', '31I', '30G', '28H', '28EY', '26Y', '13FEL', '180VMP', '16Y', '142M<sub>3</sub>', '13FE', '120N', '181M', '37N', '31Q', '33EA', '33EYA', '35FA', '35YA', '36A', '50RA', '55A', '35LV', '55EA', '85VA', '85VY', '87F', '9F', '28D', '111R', '11L', '11M', '127P<sub>2</sub>', '178L', '56A', '84DEAV', '84VGPM', '83A', '8V', '96A', '96K<sub>2</sub>', '9H', '9Y', '9YL', '8VG', '76V', '76I', '57D', '65L', '65LE', '65LK', '69R<sub>2</sub>', '77R', '75V', '75IL', '75I', '74R', '78V<sub>2</sub>', '85A', '96ES<sub>2</sub>', '74E', '96EV', '96QK<sub>2</sub>', '96Y<sub>2</sub>', '98E', '98KN', '125G', '96Q', '71A', '70RE', '70R', '37S', '38L', '4Q', '57S', '57V', '70QA', '70QRA', '70QT', '37FV', '13GM', '52PR', '52SK<sub>5</sub>', '55RL<sub>3</sub>', '55RPD', '56PA', '52PQ<sub>2</sub>', '66DR', '66IT', '67VG', '74SV<sub>2</sub>', '66D', '47QL<sub>5</sub>', '47KHL', '45GV', '160S', '167R', '175E', '185I', '25FT', '26L', '30H', '40ERV', '41RA<sub>2</sub>', '45G', '45GE<sub>3</sub>', '140A<sub>2</sub>', '160AD'], 'cutoff': '13769'}
#
#
# {'painel': '19d3d4be39cf4520cfdeaccd1cdc1148', 'analysis': ['199V', '162GLS', '163LS/G', '163LG', '166ES', '162DLS'], 'cutoff': '1614'}
#
#
# {'painel': '1a53f477f9d8cfda348abeaeedaa5c49', 'analysis': ['78V<sub>2</sub>', '45GE<sub>3</sub>', '135G', '96QK<sub>2</sub>', '70R', '70RE', '112Y', '96A', '48Q<sub>6</sub>', '4Q', '57A', '180VMP', '13FEY', '181M'], 'cutoff': '1321'}
#
#
# {'painel': '1a54ed0d8ca0bdb0cf54794977feb05a', 'analysis': ['9F', '96Y<sub>2</sub>', '129H', '26L', '98E', '40ERV', '87F', '37YA', '30Y', '96QK<sub>2</sub>', '40GR<sub>3</sub>', '116V', '125G', '185I', '25FT', '71E', '74EL', '70RT', '70GT', '67VT', '37D<sub>2</sub>', '31FYY', '66IT', '75S<sub>3</sub>', '78V<sub>2</sub>', '75IL', '9H', '77T', '76L', '160AE', '37L', '133RS', '56PA', '74L', '55RL<sub>3</sub>', '55PPA', '55PP', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '47KHL', '45GE<sub>3</sub>', '55PPD', '13FEY', '25Q<sub>3</sub>', '181M', '180VMP', '16Y', '66IL', '66ER', '66DR', '66D', '61FT<sub>4</sub>', '40YD<sub>2</sub>', '4Q', '56E<sup>DR11</sup>', '45EV', '56EE<sup>DR11</sup>', '175E', '84QL<sub>3</sub>', '57DE<sup>DP</sup>', '57S', '58EE<sup>DP</sup>', '57DE', '67F', '37YV', '35LV', '70D', '65LE', '76V', '70DK', '70DR', '70DRA', '13GM', '135G', '70QKA', '70QE', '160S', '57D', '70DA', '167H<sub>2</sub>'], 'cutoff': '1090'}
#
#
# {'painel': '1b0946f2e38b96dae4ee1509824478bd', 'analysis': ['13FE', '9F', '96A', '74SV<sub>2</sub>', '70QT', '56EE<sup>DR11</sup>', '70QRA', '13SE', '181T', '56EE', '41RA<sub>2</sub>', '38L', '85A', '77N+85VG', '185I', '26L', '56PD', '30Y', '71K', '180VTP', '71E', '178M', '167H<sub>2</sub>', '37N', '37S', '37YV', '74A', '71A', '74R', '77N', '45EV', '45GV', '70QK', '31FYY', '52SK<sub>5</sub>', '31FH', '96Y<sub>2</sub>', '13FEL', '70DA', '30H', '140TV', '30G', '142M<sub>3</sub>', '28H', '75S<sub>3</sub>', '28EY', '16Y', '28EH', '28DY', '65LE', '28D', '149H', '98KS', '98Q', '13SEF', '125G', '96HK', '47F', '52PR', '32H', '28D', '96ES<sub>2</sub>', '70QA', '70Q', '70DRA', '66EV', '74EL', '96EV', '58EE<sup>DP</sup>', '37YA', '25RF', '55PP', '55PPD', '11STS', '66ER', '25R', '70RT', '26Y', '52PQ<sub>2</sub>', '52PL<sub>3</sub>', '67VG', '67VT', '85VA', '57S', '67F', '46VY<sub>3</sub>', '77T', '160AE'], 'cutoff': '1001'}
#
#
# {'painel': '1b1c09cb5bab0264ce057dc8889ddcbe', 'analysis': ['57S', '9F', '4Q', '37YV', '37S', '67F', '67I', '70DA', '70D', '87F', '70QA', '70DRA', '85VY', '85VA', '77T', '127P<sub>2</sub>', '13FE', '11M', '70DR', '67VG', '181M', '66EV', '66ER', '180VMP', '120N', '16Y', '142M<sub>3</sub>', '111R', '26L', '74SV<sub>2</sub>', '74EL', '70RT', '11L', '32YN', '32Y', '31I', '31FYY', '31FYN', '30G', '28H', '67VT', '31FY', '13FEL', '96QK<sub>2</sub>', '55PP', '55PPD', '55RL<sub>3</sub>', '55RPD', '56PD', '125G', '98KN', '98E', '96Y<sub>2</sub>', '96Q', '96EV', '96ES<sub>2</sub>', '85A', '52SK<sub>5</sub>', '52PR', '52PQ<sub>2</sub>', '45EV', '41RA<sub>2</sub>', '37YA', '30Y', '30H', '52PL<sub>3</sub>', '78V<sub>2</sub>', '167H<sub>2</sub>', '185I', '77TY', '77T', '57D', '56A', '55EA', '55A', '50RA', '31Q', '33EYA', '35YA', '45GV', '69R<sub>2</sub>', '74E', '74A', '73A', '71R', '71E', '71A', '70RE', '70R', '70QT', '70QRA', '9YL', '9H', '76I', '76V', '84DEAV', '96A', '46VY<sub>3</sub>'], 'cutoff': '10012'}
#
#
# {'painel': '1b395844c87f8cda765ef1057c51f9d3', 'analysis': ['9D', '95V', '91R', '90D', '152RR', '152W', '163RW', '170RH', '186R', '193PL', '152HA', '107W', '144TKH', '145HT', '163R', '145KHA', '145RT', '149TAH', '14W', '17S', '73ID', '76EG', '65RK', '245V', '30G', '43Q+62GE', '56R', '62GK'], 'cutoff': '1063'}
#
#
# {'painel': '1ba297af064908ef73894250169efa33', 'analysis': ['245V', '199V', '162GLS', '186R', '163LG'], 'cutoff': '1006'}
#
#
# {'painel': '1c0194fd9be8691a37cd778574879ad9', 'analysis': ['62RR', '62LQ', '56E', '65QKR+76VS', '66IF+163TEW', '70IAQ', '2I', '35Q', '162DLS', '161D', '158T', '163RG', '186R', '184R', '44KM', '245V', '267QE', '270C', '30G', '145RT', '131S+163T', '76VS', '73TVS', '76ANT', '76VRN', '73ID', '97W', '99S', '9D', '9T'], 'cutoff': '1171'}
#
#
# {'painel': '1c5e355f92f84aa11c2bec676cc31edb', 'analysis': ['151AHV', '145KHA', '144TKH', '144KR+127K', '97V', '95V', '127K', '107W', '65GK', '62GRN', '62GE', '66KH'], 'cutoff': '1139'}
#
#
# {'painel': '1c87d4775f15cd8d3bc76acd5db9d32a', 'analysis': ['145HT', '113HN', '143S+76ESN', '144QL', '248M', '66IF', '103M', '113HD', '245TA', '65RK', '69AA+65QI', '69AA', '163LG', '163EW+73TE', '163EW+66I', '162DLS', '158T', '180E', '177DT', '177DK', '62GRN', '62GK', '62GE', '97V', '97T', '71ATD', '71KA', '113H', '70IAQ', '95V', '97N', '97S', '43Q+62GE', '65QIA+76ESN', '66IF+163TEW', '69AA+76E', '65QIA', '71SA', '107W', '66IY', '30G'], 'cutoff': '1174'}
#
#
# {'painel': '1d4875adf8e4c9bce82e0d9b154402ac', 'analysis': ['52PR', '52SK<sub>5</sub>', '41RA<sub>2</sub>', '55RPD', '47QL<sub>5</sub>', '31I', '30H', '47KHL', '40ERV', '45GV', '52PQ<sub>2</sub>', '66IT', '30G', '28H', '70QE', '13FEL', '55RL<sub>3</sub>', '74E', '74SV<sub>2</sub>', '75I', '75IL', '85VA', '85VY', '67VG', '13FE', '4Q', '78V<sub>2</sub>', '87F', '9F', '96QK<sub>2</sub>', '98KN', '125G', '135G', '160AD', '175E', '70RE', '70R', '96ES<sub>2</sub>', '180VMP', '181M', '25FT', '96EV'], 'cutoff': '10451'}
#
#
# {'painel': '1df28327f77495395c5e09506f13c12c', 'analysis': ['40YD<sub>2</sub>', '37L', '25Q<sub>3</sub>', '56PS', '37YV', '135G', '125SQ', '74SR<sub>3</sub>'], 'cutoff': '1337'}
#
#
# {'painel': '1e49fddc61ef360106bf798f5ae22279', 'analysis': ['82LR+145RA', '82LR+145R', '82LR+144QR', '80TA', '82LR', '81ALR', '80TLR', '82LR+90A', '82LR+138M', '97V', '91R', '79GT+90D', '80I+90A', '144KR', '144K', '131S+163T', '127K', '114Q', '166ES', '177DT', '151AHV', '144KR+151H', '71ATD', '166DG', '144QL', '151AHE', '152HA', '150AH', '150AAH', '149TAH', '149AH', '145RT', '152W', '158T', '163LS/G', '163R', '145KHA', '163RW', '144TKH', '156DA', '186R', '65RNA+80I', '66IF', '71SA', '71TD', '71TN', '66KH', '66KA', '73ID', '76ED', '76ESI', '76VDT', '77D', '80I', '80I+69TNT', '151H', '62QE+56G', '62RR', '66NM', '30G', '62GRN', '62GE', '62EE', '44RT+69TNT', '44RMA', '44RT'], 'cutoff': '1176'}
#
#
# {'painel': '204bc568da8a60a88477efe8f51dd73d', 'analysis': ['145KHA', '66IY', '30G', '65QIA+76ESN', '144TKH', '127K', '2I', '65GK', '151AHE', '180E', '143S+76ESN', '44KM', '177DT', '177DK', '41T', '32L', '16S', '166ES', '166DG', '97S', '163RW', '114H', '62EE', '56E', '144K', '45KE', '97N', '163RG', '163LS/G', '152HA', '151H', '151AHV', '151AHA', '150AH', '144KR', '150AAH', '149AH', '163R', '211T', '245TA', '76ESN', '24T', '161D', '144KR+151H', '71TTS', '69TNT+80N', '66KH', '70IAQ', '71ATD'], 'cutoff': '1133'}
#
#
# {'painel': '20d55548fd1171fee085649c65b9d3d7', 'analysis': ['158T', '73TVS', '76ANT', '76VRN', '76VS', '77D', '79GT+90D', '80I+69TNT', '163E', '162DLS', '71TN', '71QS', '156QA', '2I', '152W', '152RA', '152HA', '152A', '82LR+138T', '71SA', '90D', '94I', '44KM', '144KR+151H', '45EE', '62GE', '113HN', '113YD', '114Q', '114R', '116D', '116F', '11AV', '143S', '143S+76ESN', '144K', '144KR', '56E', '144TKH', '145RT', '163EW', '151H', '151AHV', '151AHE', '151AHA', '150AH', '150AAH', '14W', '149TAH', '149AH', '97S', '147L', '97T', '97V', '99S', '9F', '9T', '145KHA', '163EW+66I', '76VDT', '70IAQ', '180E', '184A', '184H', '267QE', '193AV', '163RG', '193LV', '193PV', '194V', '1C', '207S', '163RW', '245AS', '245TA', '253Q', '71ATD', '177DT', '173K', '248M', '177DK', '69RT', '62RR', '62GRN', '69AA+65QI', '163R', '66IF+163TEW', '66IF', '163LW+65QIT', '62QE+56G', '163LW', '66IY', '65RK', '65QKR+76VS', '65QIA', '66NM', '69AA', '65QKR', '65RNA+80I'], 'cutoff': '10365'}
#
#
# ...
#
#
# {'painel': 'ed8ad842e16cbd49dad657e158895f71', 'analysis': ['25Q<sub>3</sub>', '181M', '180VMP', '78V<sub>2</sub>', '96QK<sub>2</sub>', '96Y<sub>2</sub>', '98E', '125G', '125SQ', '160D', '74E', '70QRA', '57A', '4Q', '70R', '70RE', '56PV', '67VG', '70GT', '74SR<sub>3</sub>', '85VA', '85VY', '86G<sub>2</sub>', '87F', '56PS', '55RPD', '30H', '37YV', '3P<sub>4</sub>', '41KA<sub>2</sub>', '47QL<sub>5</sub>', '52PQ<sub>2</sub>', '52SK<sub>5</sub>', '41RA<sub>2</sub>'], 'cutoff': '1064'}
#
#
# {'painel': 'ed8c916ef84f6c793ad2c28e0dd7a9b7', 'analysis': ['71E', '70QKA', '55PPA', '55PP', '45EV', '112Y', '40YD<sub>2</sub>', '55PPD', '65LE', '57D', '69R<sub>2</sub>', '9H', '76V', '55EA', '35LV'], 'cutoff': '1575'}
#
#
# {'painel': 'ede972f837fe37089451f08a9bc9233a', 'analysis': ['16S', '14W', '147L', '145RT', '144QL', '144KR+151H', '144KR', '143S+76ESN', '143S', '158T', '11AV', '116L', '116F', '114R', '114Q', '113YN', '113HN', '103M', '152HA', '131S+163T', '76ESN', '163R', '163LW+65QIT', '163LS/G', '163RW', '166DG', '9T', '9D', '99S', '97T', '97S', '162GLS', '97M', '79GT+90D', '80I+69TNT', '80TA', '82LR+138M', '90D', '95W', '275K', '270C', '267QE', '245V', '245AS', '21H', '211T', '199V', '170RH', '177DK', '180E', '41T', '186R', '156DA', '152W', '193PL', '184R', '44RT+69TNT', '69TNT', '69TNT+80N', '70IAQ', '71QS', '71TD', '69RA', '71TN', '73AN', '73AS', '73ID', '76ES', '71TTS', '66IY', '76ANT', '66IS', '45KE', '62EE', '62RN', '62QE+56G', '63NI', '65GK', '65QIA+76ESN', '66IF', '62RR'], 'cutoff': '10427'}
#
#
# {'painel': 'edfc44e393e4533f75010b602ff36add', 'analysis': ['66DR', '67VG', '85VA', '75V', '77R', '85VY', '74SV<sub>2</sub>', '66D', '52SK<sub>5</sub>', '56PA', '55RPD', '55RL<sub>3</sub>', '55PPA', '52PR', '52PQ<sub>2</sub>', '47QL<sub>5</sub>', '47KHL', '45GV', '45GE<sub>3</sub>', '45G', '41RA<sub>2</sub>', '56PV', '87F', '111R', '40ERV', '9YL', '9Y', '9H', '96K<sub>2</sub>', '96A', '8VG', '8V', '84DEAV', '76V', '76I', '69R<sub>2</sub>', '9F', '57D', '55EA', '50RA', '35YA', '33EYA', '31Q', '28D', '178M', '127P<sub>2</sub>', '11M', '11L', '96ES<sub>2</sub>', '30H', '57S', '57A', '4Q', '37S', '31I', '30G', '28H', '181M', '180VMP', '142M<sub>3</sub>', '13FE', '120N', '112Y', '70DK', '13FEL', '26L', '167R', '160D', '140A<sub>2</sub>', '13GM', '125G', '98KN', '185I', '96Y<sub>2</sub>', '98E', '70R', '71A', '70RE', '74E', '74L', '78V<sub>2</sub>', '96EV', '96Q', '96QK<sub>2</sub>'], 'cutoff': '10303'}
#
#
# {'painel': 'ee8d532ef1dcb23c2b3367aed9583895', 'analysis': ['245V', '245TA', '186R', '180E', '17S', '177DT', '177DK', '62LQ', '62GK', '56R', '56E', '107W', '44KM', '43Q+62GE', '30G', '2I', '143S+76ESN', '144TKH', '145HT', '145KHA', '163RG', '102H', '163LG', '162DLS', '161D', '152W', '152RR', '77NGT', '76EG', '95V', '97S', '9T', '76ANT', '76ESN', '73ID', '65QIA+76ESN', '65RK', '66IY', '69TNT+80N', '70IAQ', '71TTS'], 'cutoff': '1075'}
#
#
# {'painel': 'eed3f94970eab89aad63c924ec444349', 'analysis': ['74SR<sub>3</sub>', '75IL', '74SV<sub>2</sub>', '96ES<sub>2</sub>', '37F', '55RL<sub>3</sub>', '28H', '26Y', '26L', '180VMP', '56PV', '16Y', '142M<sub>3</sub>', '13SEY', '13FEL', '13FE', '112Y', '56PS', '30G', '85VY', '69R<sub>2</sub>', '76I', '76V', '84DEAV', '8V', '8VG', '96K<sub>2</sub>', '9H', '9Y', '9YL', '76L', '75V', '75S<sub>3</sub>', '96A', '65LE', '57D', '86G<sub>2</sub>', '111R', '11L', '127P<sub>2</sub>', '28D', '31Q', '33EYA', '35LV', '35YA', '50RA', '55A', '55EA', '56A', '77R', '37FV', '28EY', '74R', '71A', '85A', '74L', '57V', '70DK', '45EV', '45GE<sub>3</sub>', '47KHL', '55PPD', '78V<sub>2</sub>', '70QE', '40GR<sub>3</sub>', '96EV', '160D', '160S', '125SQ', '38L', '135G', '23L', '37S', '37N', '30H', '57A', '37YV', '160AE'], 'cutoff': '1019'}
#
#
# {'painel': 'ef89eae18fa978f9ac7ddc75fc29b3b2', 'analysis': ['96A', '96ES<sub>2</sub>', '96EV', '85A', '40GR<sub>3</sub>', '9H', '55RL<sub>3</sub>', '70DRA', '70DR', '67F', '58EE<sup>DP</sup>', '57DE<sup>DP</sup>', '56EE<sup>DR11</sup>', '56E<sup>DR11</sup>', '40YD<sub>2</sub>', '37S', '37L', '57DE', '71A', '58EE<sup>DP</sup>', '57DE<sup>DP</sup>', '57D', '56EE', '56E<sup>DR11</sup>', '56E', '56EE<sup>DR11</sup>', '28D', '178M', '65LK', '78V<sub>2</sub>', '30G', '28H', '26L', '25Q<sub>3</sub>', '180VMP', '142M<sub>3</sub>', '13FEL', '65LE', '13FE', '16Y'], 'cutoff': '1085'}
#
#
# {'painel': 'f0019f4f7c24c0cb6eda3b8902a019e6', 'analysis': ['62QE+56G', '65RNA+80I', '65RNA', '66N', '65QIA', '62QE', '62LQ', '65QIA+76ESN', '66NH', '66NM', '73ID', '71SA', '70IAQ', '69AA+76E', '69AA+65QI', '69AA', '62EE', '56R', '17S', '186R', '76ANT', '163RW', '275EL', '248M', '76EG', '97I', '152RR', '152HA', '14W', '145RT', '152W', '9T', '9S', '144KR+151H', '144KR', '163R', '90D', '82LR+138M', '79GT+90D', '77NGT', '102H', '138MI+79GT', '138MI', '114Q', '245AS'], 'cutoff': '1156'}
#
#
# {'painel': 'f04ec8a32b8bd49d5a5b920258f05a8f', 'analysis': ['66IS', '66KA', '152A', '66KH', '66NM', '152HA', '71ATD', '71SA', '71TN', '73AS', '73ID', '74Y', '71KA', '65RNA+80I', '65RK', '41T', '43Q+62GE', '44KM', '44RMA', '44RT', '44RT+69TNT', '56E', '62EE', '62GE', '62GK', '62GRN', '62LQ', '62QE+56G', '62RR', '65GK', '76ANT', '76ED', '76ESI', '82LR+90A', '162DLS', '79GT+90D', '162GLS', '80I', '80I+69TNT', '80I+90A', '80TA', '80TLR', '81ALR', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '161D', '30G', '156QA', '90D', '91R', '94I', '95V', '95W', '97M', '97T', '97V', '99F', '99S', '9F', '9H', '9T', '156WA', '32L', '24T', '149AH', '145RT', '2I', '145HT', '144TKH', '144KR+151H', '144KR+127K', '144KR', '144K', '127K', '116S', '149TAH', '116L', '114R', '114Q', '163LS/G', '163LG', '163LE', '163L', '163EW+73TE', '150AH', '151AHA', '151AHE', '151AHV', '163EW+66I', '152RA', '151H', '116D', '14W', '145KHA', '163LW', '248M', '245V', '245AS', '21H', '219W', '211T', '207S', '150AAH', '193PL', '193LV', '193AV', '186R', '184A', '173K', '163LW+65QIT', '163R', '177DK', '163RW', '102H', '163RG', '16S', '113HD', '113YD', '114H', '166DG', '166ES', '107W'], 'cutoff': '10133'}
#
#
# {'painel': 'f0ee61283c8e0f98241bff1c3ca0f176', 'analysis': ['66N', '66NH', '66NM', '66NV', '71QS', '71SA', '76ANT', '65RNA+80I', '79GT+90D', '138MI', '138MI+79GT', '144KR', '144KR+151H', '145RT', '152HA', '114Q', '97M', '97I', '114R', '82LR+138M', '65RNA', '275EL', '62EE', '62GRN', '62QE', '62QE+56G', '62RR', '245AS', '163R', '163RW', '9T', '77NGT'], 'cutoff': '6578'}
#
#
# {'painel': 'f15381ff5b0096fe7485b4f9ed04cce9', 'analysis': ['77N', '74R', '74L', '74E', '73GQ', '73G', '40ERV', '71K', '77N+85VG', '70RE', '70QQ', '70QK', '70DK', '40GR<sub>3</sub>', '78V<sub>2</sub>', '55PP', '52PL<sub>3</sub>', '47QL<sub>5</sub>', '23L', '185I', '175E', '160D', '160AE', '135G', '98Q', '98E', '96Y<sub>2</sub>', '96HK', '96H', '58EE<sup>DP</sup>', '55PPA', '57V', '57DE<sup>DP</sup>', '28EH', '45GE<sub>3</sub>', '26Y', '25Q<sub>3</sub>', '189S', '28EY', '149H', '47KHL', '13SEY', '13SEF', '13SE', '13FEY', '16Y', '31FH', '57DE', '57A', '56EE<sup>DR11</sup>', '56E<sup>DR11</sup>', '51R<sub>2</sub>', '4Q', '48Q<sub>6</sub>', '104AK', '37YV', '37L', '37FV', '45EV', '37FL<sub>2</sub>', '37F', '31FYY', '57S', '11STS', '112Y', '61FT<sub>4</sub>', '84QL<sub>3</sub>', '76L', '75S<sub>3</sub>', '75IL', '66IL', '66IT', '55PPD', '55RL<sub>3</sub>', '56PA'], 'cutoff': '10609'}
#
#
# {'painel': 'f167e34c6285ea609666ead821a4a14e', 'analysis': ['73TVS', '91R', '248M', '193LV', '173K', '30G', '56E', '44RT+69TNT', '44KM', '144KR+151H', '144KR+127K', '144KR', '103M', '151AHA', '163LG', '162DLS', '152HA', '156QA', '152T', '161D'], 'cutoff': '1484'}
#
#
# {'painel': 'f242e71461ce805e3203a0d43ca7689c', 'analysis': ['16S', '177KT', '17S', '186R', '193LV', '1C', '211T', '248M', '161D', '103M', '138K', '152RA', '152T', '71SA', '73AS', '73ID', '76EG', '76ESI', '97V', '99S', '102H', '275G', '56R', '62GRN', '65RNA+80I', '9T'], 'cutoff': '1449'}
#
#
# {'painel': 'f2fc7d4c45864637a5ecb68a7c0bceae', 'analysis': ['135G', '96QK<sub>2</sub>', '96EV', '78V<sub>2</sub>', '56PS', '71A', '45GE<sub>3</sub>', '28DHF', '25Q<sub>3</sub>', '181M', '180VMP', '28H', '13FE', '133RS', '70QKA', '31I', '4Q', '48Q<sub>6</sub>', '98KN', '57D', '65LE', '69R<sub>2</sub>', '55EA', '76I', '84DEAV', '9H', '9YL', '76V', '35LV', '35YA', '111R', '11L', '31Q', '33EYA', '11M'], 'cutoff': '1254'}
#
#
# {'painel': 'f35feb5fc825337c979a8d202d0c5a70', 'analysis': ['35LV', '65LE', '57D', '55EA', '9H', '76V', '25Q<sub>3</sub>'], 'cutoff': '1432'}
#
#
# {'painel': 'f3b961ddf2d5d5ed1bccf156777f208a', 'analysis': ['9S', '173K', '163LS/G', '97N', '166DG', '166ES', '177DT', '177KT', '17S', '184R', '186R', '193LV', '193PL', '219W', '245V', '162GLS', '138K', '144QL', '97W', '145RT', '248M', '152RA', '152RR', '97V', '152T', '152W', '156DA', '113YN', '270C', '69RA', '71ATD', '71KA', '71SA', '71TD', '73AN', '73AS', '73ID', '73TVS', '76ED', '76EG', '76ESI', '76ET', '76VRN', '76VS', '80TA', '82LR+138M', '80TLR', '275G', '275K', '35Q', '44RMA', '56R', '62EE', '267QE', '62GRN', '65GK', '65QKR+76VS', '65RNA+80I', '66IF+163TEW', '91R', '62LQ', '103M', '14W', '99S', '9D', '99F', '102H'], 'cutoff': '1003'}
#
#
# {'painel': 'f4deaba01b5f9d7ab53593b7d5a7e0b7', 'analysis': ['73GQ', '50QA', '83T', '84GGPM', '84VGPM', '57S', '57V', '70QK', '85GPM', '96A', '73G', '71K', '35FA', '74R', '96H', '96HK', '96Y<sub>2</sub>', '98E', '98Q', '78V<sub>2</sub>', '31M', '28D', '178M', '77N', '127L<sub>2</sub>', '111K', '77N+85VG', '13SE', '37YV', '16Y', '149H', '13SEF', '11STS', '37FV', '37F', '26Y', '31FH', '28EY', '28EH', '31FYY', '104AK'], 'cutoff': '1239'}
#
#
# {'painel': 'f5df221ddb7b756da884a91df1150f63', 'analysis': ['45EV', '74L', '96EN<sub>3</sub>', '96HK', '71E', '70DK', '108T', '112Y', '11STS', '16Y', '57A', '6C<sub>2</sub>', '70DA', '70DRA'], 'cutoff': '1382'}
#
#
# {'painel': 'f62166264c2cbdc85871dc22ee44bec3', 'analysis': ['144QL', '144KR+127K', '65GK', '71TN', '76ED', '71TD', '71SA', '80I', '80I+69TNT', '71ATD', '65RNA+80I', '199V', '80TA', '80TLR', '81ALR', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A', '162DLS', '80I+90A'], 'cutoff': '2247'}
#
#
# {'painel': 'f66a89f29ee6cebd8ee429b21236f104', 'analysis': ['44RT', '73TVS', '156QA', '156RA', '156DA', '163EW', '163EW+66I', '163EW+73TE', '163LS/G', '163LW+65QIT', '163E', '163R', '152RA', '144KR+127K', '145RT', '152T', '147L', '151AHA', '151ARV', '149TAH', '163RG', '163RW', '166DG', '248M', '24T', '267QE', '275G', '245AS', '275K', '32L', '35Q', '41T', '2I', '21H', '219W', '173K', '177KT', '180E', '184H', '186R', '193LV', '193PL', '193PV', '1C', '143S', '97S', '97T', '99F', '99S', '9D', '9T', '73AS', '73AN', '71TN', '71KA', '9H', '95W', '94I', '76ESI', '76VRN', '76VS', '95V', '80I+69TNT', '80K+14R', '80TLR', '82LR+138M', '90D', '91R', '80K', '73ID', '70IAQ', '69RA', '62GE', '62EE', '56E', '45KE', '102H', '103L', '107W', '113H', '113HD', '113HN', '113YD', '114Q', '116L', '116S', '69RT', '69AA+65QI', '66KH', '66KA', '66K', '66IY', '66IS', '62LQ', '65RK', '65QKR+76VS', '65QKR', '65QIA+76ESN', '65QIA', '65GK', '66IF'], 'cutoff': '11018'}
#
#
# {'painel': 'f7e89e2ee629597e722d180ef26f2415', 'analysis': ['71ATD', '71SA', '71TD', '65RNA+80I', '62GRN', '65GK', '71TN', '81ALR', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '80TLR', '82LR+145RA', '97V', '82LR+90A', '80TA', '76ED', '76ESI', '80I', '80I+69TNT', '80I+90A', '144QL', '144KR+127K', '161D', '199V'], 'cutoff': '1312'}
#
#
# {'painel': 'f87f0639a50f6037faf7af5344d28d89', 'analysis': ['193PL', '184R', '14W', '163LG', '99S'], 'cutoff': '436'}
#
#
# {'painel': 'f9763c7c46bcdab3814e1707c7fe2c73', 'analysis': ['28EY', '57V', '180VMP', '9F', '26L', '16Y', '13FEL', '38L', '11L', '31Q', '127P<sub>2</sub>', '11M', '13FE', '37FL<sub>2</sub>', '30G', '111R', '96EV', '52PQ<sub>2</sub>', '52PR', '85VY', '52SK<sub>5</sub>', '55RPD', '56PV', '66D', '47KHL', '66DR', '67VG', '70GT', '85VA', '77R', '74SV<sub>2</sub>', '33EYA', '75V', '45GE<sub>3</sub>', '41RA<sub>2</sub>', '74L', '78V<sub>2</sub>', '85A', '87F', '96ES<sub>2</sub>', '125G', '140A<sub>2</sub>', '30H', '69R<sub>2</sub>', '76I', '76V', '84DEAV', '96A', '9H', '9YL', '35LV', '65LE', '35YA', '50RA', '55EA', '56A', '55A', '57D'], 'cutoff': '10626'}
#
#
# {'painel': 'f9a11ab1753bd7aa49028389cca17fe1', 'analysis': ['211T', '184R', '17S', '16S', '102H', '138K', '144KR+127K', '152W', '144QL', '14W', '62LQ', '66IF+163TEW', '56R', '30G'], 'cutoff': '437'}
#
#
# {'painel': 'f9c4cbb6ef5a0ac8e45d7e63d5c1edc9', 'analysis': ['151AHE', '151AHV', '65QIA', '65RK', '62RR', '62RN', '62GE', '62EE', '150AH', '44RT+69TNT', '44RT', '63NI', '65RNA+80I', '14W', '144KR', '144K', '131S+163T', '127K', '116L', '114H', '150AAH', '107W', '103M', '103L', '144TKH', '145KHA', '145RT', '149AH', '149TAH', '35Q', '156QA', '156R', '156RA', '162DLS', '162GLS', '163LG', '163LS/G', '156DA', '163R', '163RW', '166DG', '166ES', '170RH', '151H', '248M', '199V', '193PL', '193LV', '152A', '152HA', '152RA', '186R', '90D', '66IF', '80TA', '80TLR', '81ALR', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A', '95V', '97N', '66IC', '97W', '99F', '99S', '9D', '144KR+151H', '80I+90A', '144QL', '80I', '66IY', '80I+69TNT', '66KH', '66NM', '69AA', '69AA+65QI', '69AA+76E', '70IAQ', '71KA', '66KA', '71TD', '73AS', '76ED', '79GT+90D', '71SA', '71TN'], 'cutoff': '11419'}
#
#
# {'painel': 'fbfda65aa247cf91fc26fb9c96cb0594', 'analysis': ['162DLS', '162GLS', '163LG', '163LS/G', '163RW', '184A', '166ES', '163R', '107W', '114Q', '114R', '144QL', '144TKH', '145KHA', '193AV', '145RT', '151AHA', '151AHE', '152HA', '9T', '149TAH', '245AS', '66NM', '65RNA+80I', '65RK', '62RR', '62QE+56G', '62GE', '45KE', '44KM', '41T', '71SA', '71TN', '207S', '245V', '95V', '90D', '82LR+144QR', '82LR+138T', '80TLR', '80TA', '80I+69TNT', '79GT+90D', '76ESI', '76ED', '76ANT', '73ID'], 'cutoff': '10610'}
#
#
# {'painel': 'fc7af41c1895d6d706be046f584a158f', 'analysis': ['66DR', '66IL', '66IT', '66D', '76L', '75S<sub>3</sub>', '61FT<sub>4</sub>', '75IL', '175E', '55PPD', '55PPA', '55RL<sub>3</sub>', '55PP', '52PL<sub>3</sub>', '56PA', '47QL<sub>5</sub>', '167H<sub>2</sub>', '47KHL', '45EV', '40GR<sub>3</sub>', '40ERV', '3P<sub>4</sub>', '23L', '185I', '45GE<sub>3</sub>', '84QL<sub>3</sub>'], 'cutoff': '15427'}
#
#
# {'painel': 'ff2d411e29d8f4f53c44b67df8bef166', 'analysis': ['65GK', '65QKR', '45KE', '62GE', '41T', '32L', '65RNA+80I', '91R', '73AS', '71TN', '71TD', '71SA', '71KA', '71ATD', '66KH', '66K', '275G', '99S', '152RA', '76ESI', '145KHA', '144TKH', '144QL', '144KR+127K', '138K', '127K', '97N', '76VS', '80I', '80I+69TNT', '80I+90A', '80TA', '80TLR', '81ALR', '14W', '82LR', '82LR+138M', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A', '95V', '151AHV', '173K', '76ED', '177KT', '184H', '193LV', '193PL', '76VRN', '199V', '73TVS', '245V', '24T', '152T', '114H', '107W', '103M', '166ES', '162DLS', '162GLS', '163E', '163EW', '163EW+66I', '163LG', '163LS/G'], 'cutoff': '1594'}
#
#
# {'painel': 'ff308a7167b5a9ab4ebba9e43a0969e2', 'analysis': ['3P<sub>4</sub>', '78V<sub>2</sub>', '85A', '96ES<sub>2</sub>', '96EV', '96Q', '96QK<sub>2</sub>', '96Y<sub>2</sub>', '98E', '40ERV', '98KN', '160AE', '160D', '160S', '167H<sub>2</sub>', '37YV', '56PA', '57D', '74R', '65LE', '56PV', '56PS', '55PPD', '55PPA', '55PP', '47QL<sub>5</sub>', '47KHL', '45GE<sub>3</sub>', '45EV', '66DR', '66ER', '66IL', '70RT', '178M', '86G<sub>2</sub>', '85VY', '77R', '75S<sub>3</sub>', '74SR<sub>3</sub>', '74E', '71A', '31I', '30G', '28H', '28EY', '26Y', '26L', '181M', '180VMP', '71E', '142M<sub>3</sub>', '120N', '13FE', '13FEL', '37F', '57V', '4Q', '70DK', '67I', '37FV', '70QA', '70QT', '70RE', '70QRA', '70R', '38L', '37S', '37N'], 'cutoff': '1025'}
