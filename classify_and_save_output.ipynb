# %% [markdown]
# # Importações

# %%
import json
import joblib
import sklearn.model_selection as ms
import pandas                  as pd
import numpy                   as np
import sklearn.metrics         as mt

# %% [markdown]
# # Base de dados

# %%
db_pe = pd.read_csv('datasets/pe-dataset.csv')

db_pe.head()
# Out:
#                          panel_info panel_eplet  locus_abc  locus_dr  \
# 0  0dfaab7bd101edb0c413798f4d19e9a1        102H          1         0
# 1  0dfaab7bd101edb0c413798f4d19e9a1        103M          1         0
# 2  0dfaab7bd101edb0c413798f4d19e9a1        107W          1         0
# 3  0dfaab7bd101edb0c413798f4d19e9a1       113HD          1         0
# 4  0dfaab7bd101edb0c413798f4d19e9a1       113YD          1         0
#
#    locus_dq  locus_dp  panel_nc  panel_pc  panel_allele_count  panel_min_mfi  \
# 0         0         0       126     10803                   1            483
# 1         0         0       126     10803                   1            778
# 2         0         0       126     10803                   4           6939
# 3         0         0       126     10803                  14              0
# 4         0         0       126     10803                  14              0
#
#    panel_max_mfi  reactive
# 0            483         0
# 1            778         0
# 2          10219         1
# 3          13247         0
# 4          10472         0

# %% [markdown]
# # Selecionando atributos da base

# %%
instances_painel = db_pe.drop(columns=['panel_info', 'panel_eplet', 'reactive'])
instances_painel.head()
# Out:
#    locus_abc  locus_dr  locus_dq  locus_dp  panel_nc  panel_pc  \
# 0          1         0         0         0       126     10803
# 1          1         0         0         0       126     10803
# 2          1         0         0         0       126     10803
# 3          1         0         0         0       126     10803
# 4          1         0         0         0       126     10803
#
#    panel_allele_count  panel_min_mfi  panel_max_mfi
# 0                   1            483            483
# 1                   1            778            778
# 2                   4           6939          10219
# 3                  14              0          13247
# 4                  14              0          10472

# %%
labels_painel = np.array(db_pe['reactive'])

print(labels_painel)
# Out:
# [0 0 1 ... 0 0 0]

# %%
labels_painel
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
db_pe['panel_info'].value_counts()
# Out:
# 28f85621c895f6578ea05f6e03b499a8    250
# 1b1c09cb5bab0264ce057dc8889ddcbe    246
# 8da6126c1c996d05122425fe13196b69    241
# d5cb15b7eceeb8965bb6937b1f34cfc1    235
# b64cf228e00309ffed2febda8a0ae29c    215
# 17b6d6e71e8de8e14f1b1805b4a0efde    212
# cf914f684d44e4604c5d12e5eecf2764    210
# c317c42b6c1cdc62ac52680f4878b801    210
# a950d2818765d899d0a6078906e18379    200
# ddc6d40696e00e064d0a268f229a739d    194
# 325efd0775fd3b2288584934bfb86ce9    194
# d72848c6b111b193f5ed958b2006b4f5    194
# 469969430db09698ffea54260d7a392a    192
# 756a4732e561e2e34945a2748749649f    192
# 6773fb3c8012e79f5ab04362675cc77f    192
# c1b7ae96c751da0fec857a809b630577    192
# 1b0946f2e38b96dae4ee1509824478bd    192
# 21ccaed0ca78c37210c56bfbc667005b    192
# 560ce787cfd2b8f4b3c392670406b276    190
# 5639c77069a92483b2aeb1c9ea9d205b    189
# a6475fc907691896b42c8323b12e4844    189
# 86c2ae8ad2fd53a6dfc69c484d4594bc    189
# 423d07894993f0761189d178a5dee511    189
# 2b8ad012c2f1dadc8e225d52808e236c    189
# 98885cb05f04f6d492cbb85504db9787    187
# 1d4875adf8e4c9bce82e0d9b154402ac    186
# b897a07c3920d5f10c162aa296d36f3b    186
# 4627425eda8951a12b84a953ed0352f2    186
# 21a0cf0088e7e13ca2a8ee316ed1ed2e    186
# 63c9dc875143ef97029c4f4e3279fe7f    186
#                                    ...
# fbfda65aa247cf91fc26fb9c96cb0594    113
# cfaf0733f55495e7b9845d0f6ad46c9f    113
# 5c857fa8d4c9bf9f7b9c9be169445a7f    113
# 2e59883683f9baf2a5df4bd9a615c187    113
# 7d0b943346dd297a8cc10f678dbdbe05    113
# bcbfc140feb1bda057442edee286a088    112
# 39b525091d31b26e134386f3af3dd050    111
# 2ee8a4c5dd41332767512ca6ce6c5cf3    111
# 10f3c3287e76aa9b45145f7368f551e5    110
# 8397230f866e01026dc41a9be4fc985a    110
# 650008b5f997bb16a1b1607d9d26317a    110
# 90c233a3913ee5a4c1a751110dcd5db7    109
# 14850e049ed260aaa774d50f8f0d954e    109
# 83529eb6d0136d37212b2792aab68ec8    108
# 0b0b863da61a2da5949df2cafebe797a    108
# 3c87b18455c86ad206b4e9f0cbc8e4e4    108
# ffdaa7a29070342c2d338968ebe9902d    107
# eed3f94970eab89aad63c924ec444349    107
# 2322e08cba952a9c0f1df48fe3505121    107
# c045d476b0cfbfd4c95ee7f44090b414    106
# 0b18935a02013268dd3a0c435804f4b6    106
# bd1d3eaef36d0219383273ad279bc10b    106
# c56ffc42776605dee4428e9d45852b14    106
# 69871c9027f813d950b86bd1b8df3bbe    105
# 0f116fa2ac3abf17e1d125df6d5f20c2    105
# f2fc7d4c45864637a5ecb68a7c0bceae    105
# 039ad3ba5f8dad7097e895fd06509421    102
# 5c31bb77fd224c5cd53921940edd82ab    102
# b4fdf725641df440c925e71b45ad18e3    100
# 96526bac863f4df9ef4e4b08af0becd8     96
# Name: panel_info, Length: 550, dtype: int64

# %% [markdown]
# # Carregando o Modelo Persistido

# %%
# Modelo treinado com a base de SP
joblib_model = joblib.load("persisted_model/joblib_final_model.pkl")
print(joblib_model)
# Out:
# RandomForestClassifier(max_features='sqrt', min_samples_leaf=4,
#                        min_samples_split=8, n_estimators=400)

# %% [markdown]
# # Classificando Epítopos

# %%
cv = 10
scoring = ['roc_auc', 'accuracy']

predicted_labels_painel = ms.cross_val_predict(joblib_model, instances_painel, labels_painel, cv=cv, n_jobs=-1)

print()
print('First step:\n')
print('- Confusion matrix (TN FP FN TP):', mt.confusion_matrix(labels_painel, predicted_labels_painel).ravel())
print("- AUC-ROC: %0.2f" % (mt.roc_auc_score(labels_painel, predicted_labels_painel)*100))
print("- Accuracy: %0.2f" % (mt.accuracy_score(labels_painel, predicted_labels_painel)*100))

scores = ms.cross_validate(joblib_model, instances_painel, labels_painel, cv=cv, n_jobs=-1, scoring=scoring)

print()
print('Second step:\n')
print("- AUC-ROC:  %0.2f (+/- %0.2f)" % (scores['test_roc_auc'].mean()*100, scores['test_roc_auc'].std()*100))
print("- Accuracy: %0.2f (+/- %0.2f)" % (scores['test_accuracy'].mean()*100, scores['test_accuracy'].std()*100))
# Out:
# First step:
#
# - Confusion matrix (TN FP FN TP): [77584   397  3103   315]
# - AUC-ROC: 54.35
# - Accuracy: 95.70
#
# Second step:
#
# - AUC-ROC:  89.59 (+/- 1.23)
# - Accuracy: 95.69 (+/- 0.17)

# %%
predicted_labels_df = pd.DataFrame(data=predicted_labels_painel.flatten())

predicted_labels_df[0].value_counts()
# Out:
# 0    80687
# 1      712
# Name: 0, dtype: int64

# %%
def returnReactiveEplets(labels):
    painels = []
    predict_eplet = []
    painel_number = db_pe['panel_info'][0]                          # Recebe o identificador do primeiro painel
    first_react_eplet = 1                                           # Flag para controlarmos o cálculo do cutoff
    cutoff = 0                                                                                                                
    
    for index in range(0, len(labels)):                             # Percorre todas as instâncias da base
        if(db_pe['panel_info'][index] == painel_number):            # Se ainda estivermos no mesmo painel
            
            if(labels[index] == 1):                                 # Se o epítopo for classificado como reativo
                predict_eplet.append(db_pe['panel_eplet'][index])   # Adiconamos à lista de epítopos classificados como reativos
                
                if(first_react_eplet):                              # Verificamos se é o primeiro epítopo reativo daquele painel
                    cutoff = db_pe['panel_min_mfi'][index]          # Inicializamos o valor do cutoff
                    first_react_eplet = 0                           # Atualizamos o valor da flag
                    
                elif(db_pe['panel_min_mfi'][index] < cutoff):       # Verificamos se o cutoff do eplet é o menor cutoff
                    cutoff = db_pe['panel_min_mfi'][index]          # Atualizamos o valor do cutoff
        else:                                                       
            results = {                                             # Se mudarmos de painel, resetamos as análises
                'result_sugestion': {"cutoff": ""},
                'result_user': {
                    'analysis': [],
                    'cutoff': ''
                }
            }
            results['result_user']['analysis'] = predict_eplet     # Preenchemos a lista de epítopos classificados como reativos
            results['result_user']['cutoff'] = str(cutoff)         # Preenchemos o valor do cutoff
            painels.append(results)                                # Adicionamos à lista de resultados
            
            painel_number = db_pe['panel_info'][index]             # Atualizamos o identificador do painel
            predict_eplet = []                                     # Resetamos a lista de epítopos classificados como reativos
            cutoff = 0                                             # Resetamos o valor do cutoff
            first_react_eplet = 1                                  # Resetamos a flag para controlarmos o cálculo do cutoff
            
    return painels

# %%
def printResults(panels):
    for index in range(0, len(panels)):
        print("Painel: " + str(index))
        print(panels[index])
        print("\n")

# %%
panels = returnReactiveEplets(predicted_labels_painel)
printResults(panels)
# Out:
# Painel: 0
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1069'}}
#
#
# Painel: 1
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['52PL<sub>3</sub>', '55PP', '55PPD', '61FT<sub>4</sub>', '66IL', '76L', '84QL<sub>3</sub>'], 'cutoff': '1889'}}
#
#
# Painel: 2
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1212'}}
#
#
# Painel: 3
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 4
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R', '46VY<sub>3</sub>'], 'cutoff': '8546'}}
#
#
# Painel: 5
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '2785'}}
#
#
# Painel: 6
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 7
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['79GT'], 'cutoff': '447'}}
#
#
# Painel: 8
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 9
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 10
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R'], 'cutoff': '4695'}}
#
#
# Painel: 11
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '5085'}}
#
#
# Painel: 12
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 13
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['63NI', '76ESN', '77SRN', '80N'], 'cutoff': '823'}}
#
#
# Painel: 14
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 15
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['65QKR'], 'cutoff': '711'}}
#
#
# Painel: 16
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 17
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 18
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['129H'], 'cutoff': '912'}}
#
#
# Painel: 19
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 20
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['12M', '131S', '163L', '163LE'], 'cutoff': '1750'}}
#
#
# Painel: 21
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['111R', '127P<sub>2</sub>', '31Q', '50RA', '84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '755'}}
#
#
# Painel: 22
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 23
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 24
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['66I'], 'cutoff': '9183'}}
#
#
# Painel: 25
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['140A', '140AV', '149Q', '31FY', '32Y', '32YN', '70QA', '70QT', '129H', '40ERV', '52PL<sub>3</sub>', '61FT<sub>4</sub>', '84QL<sub>3</sub>'], 'cutoff': '429'}}
#
#
# Painel: 26
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 27
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '887'}}
#
#
# Painel: 28
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 29
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 30
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 31
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 32
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 33
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 34
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['11L', '84DEAV'], 'cutoff': '2308'}}
#
#
# Painel: 35
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116D', '74Y', '82LR'], 'cutoff': '585'}}
#
#
# Painel: 36
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 37
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 38
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 39
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 40
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['80T'], 'cutoff': '1320'}}
#
#
# Painel: 41
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['45G', '75I', '84DEAV'], 'cutoff': '650'}}
#
#
# Painel: 42
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 43
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 44
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['150AAH'], 'cutoff': '2038'}}
#
#
# Painel: 45
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['61FT<sub>4</sub>', '84QL<sub>3</sub>'], 'cutoff': '1493'}}
#
#
# Painel: 46
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 47
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116V'], 'cutoff': '8264'}}
#
#
# Painel: 48
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 49
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 50
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 51
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 52
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 53
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 54
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 55
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 56
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 57
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['80I', '80I+90A', '82LR'], 'cutoff': '1184'}}
#
#
# Painel: 58
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 59
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ES', '76ESN'], 'cutoff': '1113'}}
#
#
# Painel: 60
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 61
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['80K+14R'], 'cutoff': '790'}}
#
#
# Painel: 62
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 63
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['114Q', '114R', '144K', '150AAH', '150AH', '184A', '245AS', '62RR', '63NI', '65RA', '65RNA', '66IY', '66N', '66NH', '71QS', '76VDT', '79GT', '79GT+90D', '97T'], 'cutoff': '665'}}
#
#
# Painel: 64
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '511'}}
#
#
# Painel: 65
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 66
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '764'}}
#
#
# Painel: 67
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 68
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 69
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1964'}}
#
#
# Painel: 70
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 71
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 72
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 73
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 74
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 75
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI'], 'cutoff': '3487'}}
#
#
# Painel: 76
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 77
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '1497'}}
#
#
# Painel: 78
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 79
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 80
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 81
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 82
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 83
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['46VY<sub>3</sub>', '84DEAV'], 'cutoff': '544'}}
#
#
# Painel: 84
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN', '77SRN', '80N'], 'cutoff': '1296'}}
#
#
# Painel: 85
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '2247'}}
#
#
# Painel: 86
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['83A', '84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '659'}}
#
#
# Painel: 87
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 88
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 89
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['75I'], 'cutoff': '10499'}}
#
#
# Painel: 90
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 91
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['52PR'], 'cutoff': '1917'}}
#
#
# Painel: 92
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 93
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['180VTP'], 'cutoff': '452'}}
#
#
# Painel: 94
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 95
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['120S', '180V', '180VTP', '98KS'], 'cutoff': '1584'}}
#
#
# Painel: 96
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 97
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 98
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['152V', '194V', '77S', '77SRN', '80N', '95L'], 'cutoff': '1621'}}
#
#
# Painel: 99
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['120S', '180V', '180VTP'], 'cutoff': '765'}}
#
#
# Painel: 100
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163EW', '76ESN'], 'cutoff': '2630'}}
#
#
# Painel: 101
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 102
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '575'}}
#
#
# Painel: 103
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 104
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI', '77N'], 'cutoff': '607'}}
#
#
# Painel: 105
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 106
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '4300'}}
#
#
# Painel: 107
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['13SEF', '31FH', '71K'], 'cutoff': '4132'}}
#
#
# Painel: 108
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 109
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['28D'], 'cutoff': '1092'}}
#
#
# Painel: 110
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 111
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['140TV', '32H', '55PP', '66ER', '111R', '31Q', '84DEAV'], 'cutoff': '427'}}
#
#
# Painel: 112
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 113
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 114
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69TNT', '82LR+138M'], 'cutoff': '3011'}}
#
#
# Painel: 115
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['55PPD', '84DEAV'], 'cutoff': '634'}}
#
#
# Painel: 116
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 117
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 118
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 119
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['80I+90A'], 'cutoff': '459'}}
#
#
# Painel: 120
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['13SE', '149H', '96H'], 'cutoff': '2021'}}
#
#
# Painel: 121
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 122
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 123
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116D', '138MI', '76ESN'], 'cutoff': '591'}}
#
#
# Painel: 124
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 125
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['12M', '163L', '66IF', '95W'], 'cutoff': '443'}}
#
#
# Painel: 126
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['52PQ<sub>2</sub>'], 'cutoff': '1871'}}
#
#
# Painel: 127
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['181M', '31I', '70QA', '70RE', '74E', '98E'], 'cutoff': '4763'}}
#
#
# Painel: 128
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 129
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['127P<sub>2</sub>', '50RA', '56A', '8V', '96K<sub>2</sub>', '9Y'], 'cutoff': '2069'}}
#
#
# Painel: 130
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 131
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 132
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 133
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 134
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 135
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '2200'}}
#
#
# Painel: 136
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 137
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['45GV'], 'cutoff': '872'}}
#
#
# Painel: 138
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '2451'}}
#
#
# Painel: 139
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 140
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['79GT'], 'cutoff': '1190'}}
#
#
# Painel: 141
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '2480'}}
#
#
# Painel: 142
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['66I', '69TNT'], 'cutoff': '4601'}}
#
#
# Painel: 143
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 144
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 145
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 146
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI'], 'cutoff': '1128'}}
#
#
# Painel: 147
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 148
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 149
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 150
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R', '4R', '46VY<sub>3</sub>'], 'cutoff': '2579'}}
#
#
# Painel: 151
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 152
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 153
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R', '52PR'], 'cutoff': '960'}}
#
#
# Painel: 154
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 155
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 156
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['85VV'], 'cutoff': '2924'}}
#
#
# Painel: 157
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116D', '65RNA', '66N'], 'cutoff': '697'}}
#
#
# Painel: 158
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 159
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 160
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 161
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 162
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['74E', '26L', '52PQ<sub>2</sub>'], 'cutoff': '999'}}
#
#
# Painel: 163
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 164
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116D', '144KR+151H', '163L', '95I'], 'cutoff': '495'}}
#
#
# Painel: 165
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 166
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['37YA', '58EE<sup>DP</sup>'], 'cutoff': '820'}}
#
#
# Painel: 167
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 168
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 169
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['57DE<sup>DP</sup>'], 'cutoff': '9346'}}
#
#
# Painel: 170
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['80K+14R'], 'cutoff': '4216'}}
#
#
# Painel: 171
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['11STS', '47F', '52PQ<sub>2</sub>'], 'cutoff': '768'}}
#
#
# Painel: 172
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 173
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 174
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 175
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 176
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['186R', '219W'], 'cutoff': '695'}}
#
#
# Painel: 177
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['70QA', '74E', '13GM', '160AD', '167R', '45G', '75I', '127P<sub>2</sub>', '50RA', '65L', '84DEAV', '9Y'], 'cutoff': '441'}}
#
#
# Painel: 178
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 179
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '2192'}}
#
#
# Painel: 180
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 181
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 182
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['46VY<sub>3</sub>'], 'cutoff': '2628'}}
#
#
# Painel: 183
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 184
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 185
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 186
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 187
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['79GT'], 'cutoff': '2350'}}
#
#
# Painel: 188
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '2088'}}
#
#
# Painel: 189
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['180V', '180VTP', '84DEAV'], 'cutoff': '3314'}}
#
#
# Painel: 190
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '3387'}}
#
#
# Painel: 191
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 192
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L'], 'cutoff': '4783'}}
#
#
# Painel: 193
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 194
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '830'}}
#
#
# Painel: 195
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['152E', '152RE', '95L'], 'cutoff': '749'}}
#
#
# Painel: 196
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 197
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 198
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 199
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '1551'}}
#
#
# Painel: 200
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '1097'}}
#
#
# Painel: 201
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['131S', '74Y', '82LR'], 'cutoff': '1151'}}
#
#
# Painel: 202
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 203
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['152E', '152RE', '9Y'], 'cutoff': '1417'}}
#
#
# Painel: 204
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 205
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['167R', '45G', '84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '2569'}}
#
#
# Painel: 206
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 207
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['30Y', '37YA', '46VY<sub>3</sub>', '77T'], 'cutoff': '2667'}}
#
#
# Painel: 208
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149AH'], 'cutoff': '1562'}}
#
#
# Painel: 209
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149H', '26F', '28DY', '31F', '31FY'], 'cutoff': '1048'}}
#
#
# Painel: 210
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1312'}}
#
#
# Painel: 211
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 212
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 213
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 214
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 215
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1346'}}
#
#
# Painel: 216
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['111R', '31Q', '84DEAV'], 'cutoff': '1337'}}
#
#
# Painel: 217
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 218
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 219
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 220
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149TAH', '151AHE', '170RH', '44RT', '44RT+69TNT', '66KA', '66KH', '66NH', '76ANT', '77NGT', '80K+14R'], 'cutoff': '703'}}
#
#
# Painel: 221
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 222
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 223
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['70QA', '11L', '57DE<sup>DP</sup>', '84DEAV'], 'cutoff': '3302'}}
#
#
# Painel: 224
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 225
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ES', '76ESN'], 'cutoff': '2352'}}
#
#
# Painel: 226
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 227
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '1629'}}
#
#
# Painel: 228
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 229
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69AA+76E', '76VDT', '9H'], 'cutoff': '331'}}
#
#
# Painel: 230
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31FYN', '57DE<sup>DP</sup>'], 'cutoff': '914'}}
#
#
# Painel: 231
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 232
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['75V'], 'cutoff': '754'}}
#
#
# Painel: 233
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 234
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 235
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['113HN', '116L', '131S+163T', '145RT', '163RW', '170RH', '41T', '44RT', '44RT+69TNT', '45KE', '62RN', '62RR', '63NI', '65RNA+80I', '66IY', '71TN', '80I+69TNT', '80I+90A', '81ALR', '82LR+138M', '95W', '97T'], 'cutoff': '461'}}
#
#
# Painel: 236
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['16H', '189R', '84DEAV'], 'cutoff': '1168'}}
#
#
# Painel: 237
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['62RN', '63NI', '65RNA'], 'cutoff': '889'}}
#
#
# Painel: 238
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>', '84DEAV'], 'cutoff': '414'}}
#
#
# Painel: 239
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 240
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 241
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 242
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69TNT'], 'cutoff': '4095'}}
#
#
# Painel: 243
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 244
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 245
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 246
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 247
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 248
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['152E', '95L'], 'cutoff': '881'}}
#
#
# Painel: 249
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 250
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L'], 'cutoff': '443'}}
#
#
# Painel: 251
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 252
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['113H'], 'cutoff': '4865'}}
#
#
# Painel: 253
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '1696'}}
#
#
# Painel: 254
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 255
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 256
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 257
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '6129'}}
#
#
# Painel: 258
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 259
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 260
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 261
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['46VY<sub>3</sub>'], 'cutoff': '3291'}}
#
#
# Painel: 262
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '82LR'], 'cutoff': '811'}}
#
#
# Painel: 263
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 264
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 265
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 266
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 267
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 268
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L'], 'cutoff': '1114'}}
#
#
# Painel: 269
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25RF'], 'cutoff': '423'}}
#
#
# Painel: 270
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '7321'}}
#
#
# Painel: 271
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 272
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69TNT'], 'cutoff': '2131'}}
#
#
# Painel: 273
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['57DE<sup>DP</sup>'], 'cutoff': '1673'}}
#
#
# Painel: 274
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31F'], 'cutoff': '1515'}}
#
#
# Painel: 275
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 276
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 277
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['114Q', '138MI', '138MI+79GT', '245AS', '275EL', '62QE', '66NH', '71QS'], 'cutoff': '807'}}
#
#
# Painel: 278
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['120N', '70QA', '70R', '74E', '84DEAV', '9Y'], 'cutoff': '1080'}}
#
#
# Painel: 279
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163EW+73TE', '65QIA', '65QIA+76ESN', '66IY', '69AA+65QI', '69AA+76E', '70IAQ', '97S'], 'cutoff': '421'}}
#
#
# Painel: 280
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31FH', '31FYN', '47F', '52PQ<sub>2</sub>', '75V'], 'cutoff': '1354'}}
#
#
# Painel: 281
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI', '156RA', '163EW', '90D'], 'cutoff': '515'}}
#
#
# Painel: 282
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31FYN', '70DR', '57D'], 'cutoff': '467'}}
#
#
# Painel: 283
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['65RNA', '79GT'], 'cutoff': '1673'}}
#
#
# Painel: 284
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 285
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 286
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 287
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['114Q', '41T', '44RT+69TNT', '45KE', '63NI', '66IS', '71TN', '76ESN', '90D', '97T'], 'cutoff': '856'}}
#
#
# Painel: 288
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 289
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 290
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '7081'}}
#
#
# Painel: 291
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['63NI', '66I', '69TNT', '76ESN'], 'cutoff': '2546'}}
#
#
# Painel: 292
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['35F', '56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '474'}}
#
#
# Painel: 293
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 294
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '458'}}
#
#
# Painel: 295
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 296
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 297
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 298
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['184A', '193AV', '207S', '245AS', '253Q', '62RR'], 'cutoff': '452'}}
#
#
# Painel: 299
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 300
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 301
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 302
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 303
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116V'], 'cutoff': '12954'}}
#
#
# Painel: 304
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '710'}}
#
#
# Painel: 305
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 306
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 307
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 308
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 309
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '971'}}
#
#
# Painel: 310
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 311
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 312
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '5712'}}
#
#
# Painel: 313
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 314
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 315
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 316
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 317
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '14274'}}
#
#
# Painel: 318
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['12M', '163L'], 'cutoff': '879'}}
#
#
# Painel: 319
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '626'}}
#
#
# Painel: 320
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1112'}}
#
#
# Painel: 321
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['96H'], 'cutoff': '1274'}}
#
#
# Painel: 322
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 323
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R'], 'cutoff': '8329'}}
#
#
# Painel: 324
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R', '46VY<sub>3</sub>'], 'cutoff': '8713'}}
#
#
# Painel: 325
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['66I', '69TNT', '76ES'], 'cutoff': '766'}}
#
#
# Painel: 326
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '7636'}}
#
#
# Painel: 327
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['46VY<sub>3</sub>', '84DEAV'], 'cutoff': '11543'}}
#
#
# Painel: 328
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31FH'], 'cutoff': '1453'}}
#
#
# Painel: 329
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69TNT', '76ES', '76ESN'], 'cutoff': '646'}}
#
#
# Painel: 330
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['140TV', '28DY', '30Y', '31F', '70D', '116V', '129H'], 'cutoff': '684'}}
#
#
# Painel: 331
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['66IS', '69TNT'], 'cutoff': '650'}}
#
#
# Painel: 332
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '1905'}}
#
#
# Painel: 333
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69AA+76E', '76ESN'], 'cutoff': '749'}}
#
#
# Painel: 334
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['111R', '11L', '31Q', '84DEAV', '9YL'], 'cutoff': '2566'}}
#
#
# Painel: 335
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31FY', '70QA'], 'cutoff': '1269'}}
#
#
# Painel: 336
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['219W'], 'cutoff': '534'}}
#
#
# Painel: 337
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['37S', '70QA'], 'cutoff': '802'}}
#
#
# Painel: 338
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['144K', '149AH', '150AH'], 'cutoff': '1975'}}
#
#
# Painel: 339
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['12M', '163L', '163LE'], 'cutoff': '627'}}
#
#
# Painel: 340
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 341
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '163LE', '82LR'], 'cutoff': '980'}}
#
#
# Painel: 342
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['61FT<sub>4</sub>', '84QL<sub>3</sub>'], 'cutoff': '1621'}}
#
#
# Painel: 343
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 344
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 345
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 346
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 347
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 348
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 349
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '14823'}}
#
#
# Painel: 350
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['113H'], 'cutoff': '518'}}
#
#
# Painel: 351
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['28D', '28DY', '84DEAV'], 'cutoff': '456'}}
#
#
# Painel: 352
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 353
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 354
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 355
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 356
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 357
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149H', '96H', '140A<sub>2</sub>', '185T', '52PR', '76L'], 'cutoff': '645'}}
#
#
# Painel: 358
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['152RE', '62RN', '63NI', '66I', '69TNT', '76ES'], 'cutoff': '800'}}
#
#
# Painel: 359
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 360
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 361
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 362
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 363
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 364
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 365
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 366
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 367
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 368
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '163LE'], 'cutoff': '3001'}}
#
#
# Painel: 369
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['55PPA'], 'cutoff': '1173'}}
#
#
# Painel: 370
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 371
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31F', '116V', '56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '1100'}}
#
#
# Painel: 372
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 373
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56PD', '66ER', '84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '593'}}
#
#
# Painel: 374
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1017'}}
#
#
# Painel: 375
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 376
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1310'}}
#
#
# Painel: 377
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['140A<sub>2</sub>', '185T', '111K', '31M', '35F', '35FV', '50QA', '56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '515'}}
#
#
# Painel: 378
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['12M', '163L', '69TNT', '74Y'], 'cutoff': '849'}}
#
#
# Painel: 379
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['32YN'], 'cutoff': '440'}}
#
#
# Painel: 380
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 381
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31FY', '30Y', '37YA', '45GV', '46VY<sub>3</sub>', '52PL<sub>3</sub>', '55PP', '56PD', '66EV', '67VT', '70RT', '74EL', '77T'], 'cutoff': '667'}}
#
#
# Painel: 382
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ES'], 'cutoff': '3192'}}
#
#
# Painel: 383
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 384
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 385
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 386
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '8838'}}
#
#
# Painel: 387
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 388
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['63NI'], 'cutoff': '1611'}}
#
#
# Painel: 389
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['37YA', '77T'], 'cutoff': '5700'}}
#
#
# Painel: 390
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 391
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 392
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['144KR', '69AA+76E'], 'cutoff': '440'}}
#
#
# Painel: 393
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['28D', '31FYY', '32H', '37YV'], 'cutoff': '711'}}
#
#
# Painel: 394
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI', '65RNA'], 'cutoff': '495'}}
#
#
# Painel: 395
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 396
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 397
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '5251'}}
#
#
# Painel: 398
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 399
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 400
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '163LE'], 'cutoff': '669'}}
#
#
# Painel: 401
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 402
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 403
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['80N'], 'cutoff': '5861'}}
#
#
# Painel: 404
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 405
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 406
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['83A'], 'cutoff': '830'}}
#
#
# Painel: 407
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 408
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '3654'}}
#
#
# Painel: 409
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 410
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['25R', '135D'], 'cutoff': '1007'}}
#
#
# Painel: 411
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116D', '151ARV'], 'cutoff': '1795'}}
#
#
# Painel: 412
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 413
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['46VY<sub>3</sub>'], 'cutoff': '3865'}}
#
#
# Painel: 414
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '74Y', '82LR'], 'cutoff': '6154'}}
#
#
# Painel: 415
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 416
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['70D', '84DEAV', '8V', '96K<sub>2</sub>'], 'cutoff': '601'}}
#
#
# Painel: 417
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['103L'], 'cutoff': '9741'}}
#
#
# Painel: 418
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 419
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN', '77SRN', '80N'], 'cutoff': '4193'}}
#
#
# Painel: 420
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 421
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 422
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 423
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['131S', '63NI', '71TN', '82LR'], 'cutoff': '467'}}
#
#
# Painel: 424
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31F', '55PP', '56PD', '84DEAV'], 'cutoff': '849'}}
#
#
# Painel: 425
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 426
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149H'], 'cutoff': '415'}}
#
#
# Painel: 427
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 428
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['13SE', '140A', '140AV', '149Q', '16H', '189R', '31FH', '32H', '37N', '57D', '57DA', '67L', '70Q', '74A', '85VV', '86V', '13GM', '167R', '45G'], 'cutoff': '520'}}
#
#
# Painel: 429
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '6741'}}
#
#
# Painel: 430
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 431
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '1473'}}
#
#
# Painel: 432
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 433
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['77N', '82LR'], 'cutoff': '2028'}}
#
#
# Painel: 434
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 435
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '82LR'], 'cutoff': '499'}}
#
#
# Painel: 436
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['11STS'], 'cutoff': '2017'}}
#
#
# Painel: 437
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 438
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '8570'}}
#
#
# Painel: 439
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['194V'], 'cutoff': '1297'}}
#
#
# Painel: 440
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 441
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['151ARV'], 'cutoff': '412'}}
#
#
# Painel: 442
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149H', '52PQ<sub>2</sub>'], 'cutoff': '1621'}}
#
#
# Painel: 443
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 444
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31I', '74E', '11L', '84DEAV'], 'cutoff': '520'}}
#
#
# Painel: 445
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 446
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['37YA', '77T'], 'cutoff': '912'}}
#
#
# Painel: 447
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['44RT+69TNT', '76VDT', '80I', '80I+90A', '81ALR', '82LR+138T', '82LR+144QR', '82LR+145R', '82LR+145RA', '82LR+90A'], 'cutoff': '1176'}}
#
#
# Painel: 448
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['135D', '37YA', '46VY<sub>3</sub>', '55PP', '111R', '31Q'], 'cutoff': '2050'}}
#
#
# Painel: 449
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 450
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['129H'], 'cutoff': '1941'}}
#
#
# Painel: 451
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 452
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['13GM', '160AD', '167R', '45G', '75I', '84DEAV', '8V', '96K<sub>2</sub>', '9Y'], 'cutoff': '1648'}}
#
#
# Painel: 453
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '976'}}
#
#
# Painel: 454
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 455
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['13GM'], 'cutoff': '992'}}
#
#
# Painel: 456
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 457
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['37N', '37S'], 'cutoff': '1316'}}
#
#
# Painel: 458
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 459
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 460
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI'], 'cutoff': '11654'}}
#
#
# Painel: 461
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 462
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 463
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 464
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['151ARV', '152V', '76ES', '76ESN', '77S', '77SRN', '80N'], 'cutoff': '1216'}}
#
#
# Painel: 465
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 466
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 467
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116V'], 'cutoff': '14598'}}
#
#
# Painel: 468
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['69TNT'], 'cutoff': '9760'}}
#
#
# Painel: 469
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 470
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 471
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['138MI'], 'cutoff': '1156'}}
#
#
# Painel: 472
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['131S', '74Y', '95I'], 'cutoff': '485'}}
#
#
# Painel: 473
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 474
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 475
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['194V'], 'cutoff': '1040'}}
#
#
# Painel: 476
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56P', '9Y', '111R', '127P<sub>2</sub>', '31Q', '50RA', '57E', '65I'], 'cutoff': '669'}}
#
#
# Painel: 477
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 478
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 479
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '11029'}}
#
#
# Painel: 480
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 481
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 482
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '3135'}}
#
#
# Painel: 483
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['116D'], 'cutoff': '652'}}
#
#
# Painel: 484
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '529'}}
#
#
# Painel: 485
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '669'}}
#
#
# Painel: 486
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 487
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 488
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['31M', '50QA'], 'cutoff': '1239'}}
#
#
# Painel: 489
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN', '77SRN', '80N'], 'cutoff': '4104'}}
#
#
# Painel: 490
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 491
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['65RA', '65RNA', '79GT', '80T', '80TL'], 'cutoff': '837'}}
#
#
# Painel: 492
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 493
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 494
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['113H'], 'cutoff': '747'}}
#
#
# Painel: 495
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 496
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['65RNA', '66N'], 'cutoff': '985'}}
#
#
# Painel: 497
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['66IY', '95W', '97T'], 'cutoff': '1614'}}
#
#
# Painel: 498
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 499
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['152RE', '82LR'], 'cutoff': '411'}}
#
#
# Painel: 500
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 501
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 502
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '529'}}
#
#
# Painel: 503
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '16131'}}
#
#
# Painel: 504
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['12M', '131S', '69TNT', '74Y', '82LR'], 'cutoff': '839'}}
#
#
# Painel: 505
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 506
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '194V', '82LR'], 'cutoff': '410'}}
#
#
# Painel: 507
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 508
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 509
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 510
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 511
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['52PQ<sub>2</sub>', '52SK<sub>5</sub>'], 'cutoff': '1329'}}
#
#
# Painel: 512
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '2516'}}
#
#
# Painel: 513
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 514
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['113H'], 'cutoff': '4428'}}
#
#
# Painel: 515
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 516
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['111R', '127P<sub>2</sub>', '31Q', '50RA'], 'cutoff': '1819'}}
#
#
# Painel: 517
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L', '163LE'], 'cutoff': '629'}}
#
#
# Painel: 518
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 519
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 520
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['149H', '96H'], 'cutoff': '1903'}}
#
#
# Painel: 521
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 522
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 523
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '4751'}}
#
#
# Painel: 524
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 525
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 526
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 527
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 528
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['84DEAV'], 'cutoff': '841'}}
#
#
# Painel: 529
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['63NI', '76ESN', '77SRN', '80N'], 'cutoff': '1289'}}
#
#
# Painel: 530
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 531
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 532
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['70Q'], 'cutoff': '468'}}
#
#
# Painel: 533
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 534
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['120S', '180V', '180VTP', '98KS'], 'cutoff': '466'}}
#
#
# Painel: 535
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['62RN', '82LR'], 'cutoff': '426'}}
#
#
# Painel: 536
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56E', '56E<sup>DR11</sup>', '57DE<sup>DP</sup>'], 'cutoff': '613'}}
#
#
# Painel: 537
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 538
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['56A', '84DEAV'], 'cutoff': '1118'}}
#
#
# Painel: 539
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 540
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 541
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '2730'}}
#
#
# Painel: 542
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['76ESN'], 'cutoff': '876'}}
#
#
# Painel: 543
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 544
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 545
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 546
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['163L'], 'cutoff': '586'}}
#
#
# Painel: 547
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': [], 'cutoff': '0'}}
#
#
# Painel: 548
# {'result_sugestion': {'cutoff': ''}, 'result_user': {'analysis': ['82LR'], 'cutoff': '3856'}}
